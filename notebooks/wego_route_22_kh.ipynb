# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import requests
import geojson
import json


# %matplotlib inline

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
Authorization
# Out:
# '5f2680b713bddbda2b2a03bf89fa4751'

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/22'

params = {
    'direction': '1',
    'startDate': '03-15-2022',
    'resolution': 'hiRes',
}
params_geo = {
    'direction': '1',
    'startDate': '03-15-2022',
    'format' : 'geojson',
    'resolution': 'hiRes',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
response_geo = requests.get(URL, params = params_geo, headers = headers)

# %%
# dig into json to get list of line-segment dicts
res = response_geo.json()['features']
res
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83379124944368, 36.21118811248282],
#     [-86.83380064271442, 36.211399461074556]]},
#   'properties': {'fromStopId': 'HAYEVENN',
#    'fromStopName': 'Haynes Park Dr & Eve Cr Nb',
#    'toStopId': 'HAYEFANN',
#    'toStopName': 'Haynes Park Dr & Fairview Dr Nb',
#    'pathLengthMeters': 23.516,
#    'averageTravelSeconds': 3.773538,
#    'averageTravelSpeed': 6.231817461491046,
#    'maxSecs': 6.876,
#    'percent90Secs': 6.24,
#    'percent80Secs': 4.787,
#    'percent70Secs': 3.922,
#    'medianSecs': 3.409,
#    'percent30Secs': 3.362,
#    'percent10Secs': 2.34,
#    'minSecs': 2.29}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84336854972544, 36.21172873578189],
#     [-86.8431025986628, 36.21168322543962]]},
#   'properties': {'fromStopId': 'TIMFAISN',
#    'fromStopName': 'Timothy Dr & Fairview Dr Sb',
#    'toStopId': 'FAICLAEN',
#    'toStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'pathLengthMeters': 24.391,
#    'averageTravelSeconds': 2.115154,
#    'averageTravelSpeed': 11.531548057493685,
#    'maxSecs': 3.474,
#    'percent90Secs': 3.124,
#    'percent80Secs': 2.552,
#    'percent70Secs': 2.228,
#    'medianSecs': 1.887,
#    'percent30Secs': 1.851,
#    'percent10Secs': 1.529,
#    'minSecs': 1.459}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84063838141061, 36.20345894231047],
#     [-86.84061007200557, 36.2032405554716]]},
#   'properties': {'fromStopId': 'CLAWHASN',
#    'fromStopName': 'Clarksville Pike & W. Hamilton Ave',
#    'toStopId': 'CLAABESN',
#    'toStopName': 'Clarksville Pike & Abernathy Rd Sb',
#    'pathLengthMeters': 24.416,
#    'averageTravelSeconds': 2.07175,
#    'averageTravelSpeed': 11.785205743936285,
#    'maxSecs': 2.267,
#    'percent90Secs': 2.267,
#    'percent80Secs': 2.267,
#    'percent70Secs': 2.258,
#    'medianSecs': 2.1085,
#    'percent30Secs': 1.886,
#    'percent10Secs': 1.803,
#    'minSecs': 1.803}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83660567237101, 36.194401139132985],
#     [-86.83683790451626, 36.19450902650756]]},
#   'properties': {'fromStopId': 'HAMHYDWN',
#    'fromStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'toStopId': 'JOHASHWF',
#    'toStopName': 'John Mallette Dr & Ashton Ave Wb',
#    'pathLengthMeters': 24.046,
#    'averageTravelSeconds': 2.742,
#    'averageTravelSpeed': 8.769511305616339,
#    'maxSecs': 3.6,
#    'percent90Secs': 3.6,
#    'percent80Secs': 3.6,
#    'percent70Secs': 3.6,
#    'medianSecs': 2.742,
#    'percent30Secs': 1.884,
#    'percent10Secs': 1.884,
#    'minSecs': 1.884}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8282551058027, 36.193190539503625],
#     [-86.82810265870404, 36.193355809255436]]},
#   'properties': {'fromStopId': 'CLSFCLK',
#    'fromStopName': 'Cliff Dr Past Clarksville Hwy',
#    'toStopId': 'CLICLANM',
#    'toStopName': 'Cliff Dr & Clarksville Pike Nb',
#    'pathLengthMeters': 22.91,
#    'averageTravelSeconds': 2.38375,
#    'averageTravelSpeed': 9.61090718405873,
#    'maxSecs': 3.402,
#    'percent90Secs': 3.329,
#    'percent80Secs': 2.855,
#    'percent70Secs': 2.728,
#    'medianSecs': 2.278,
#    'percent30Secs': 2.12,
#    'percent10Secs': 1.575,
#    'minSecs': 1.537}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84478586063629, 36.2176809284433],
#     [-86.84504683740901, 36.21765441651718]]},
#   'properties': {'fromStopId': 'KINTEMWF',
#    'fromStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'toStopId': 'CRECRESN',
#    'toStopName': 'Creekwood & Creekland Ct Sb',
#    'pathLengthMeters': 23.597,
#    'averageTravelSeconds': 1.664769,
#    'averageTravelSpeed': 14.17433890227413,
#    'maxSecs': 2.201,
#    'percent90Secs': 2.101,
#    'percent80Secs': 1.934,
#    'percent70Secs': 1.894,
#    'medianSecs': 1.644,
#    'percent30Secs': 1.436,
#    'percent10Secs': 1.215,
#    'minSecs': 1.16}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78980121306557, 36.17087030125267],
#     [-86.78992945567869, 36.171064361503205]]},
#   'properties': {'fromStopId': '8A9ANM',
#    'fromStopName': '8th Ave N & 9th Ave N Nb',
#    'toStopId': '8AJEFNF',
#    'toStopName': '8th Ave N & Jefferson St Nb',
#    'pathLengthMeters': 24.457,
#    'averageTravelSeconds': 2.0678710000000002,
#    'averageTravelSpeed': 11.827140087558652,
#    'maxSecs': 4.15,
#    'percent90Secs': 2.99,
#    'percent80Secs': 2.592,
#    'percent70Secs': 2.273,
#    'medianSecs': 1.995,
#    'percent30Secs': 1.678,
#    'percent10Secs': 1.391,
#    'minSecs': 1.284}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82475984097886, 36.18989324216121],
#     [-86.82498665722785, 36.1900232834773]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'HAMHYDWN',
#    'toStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'pathLengthMeters': 24.968,
#    'averageTravelSeconds': 1.457762,
#    'averageTravelSpeed': 17.127624399593348,
#    'maxSecs': 2.152,
#    'percent90Secs': 1.922,
#    'percent80Secs': 1.56,
#    'percent70Secs': 1.519,
#    'medianSecs': 1.459,
#    'percent30Secs': 1.351,
#    'percent10Secs': 1.155,
#    'minSecs': 1.135}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81442644172787, 36.181640303435195],
#     [-86.81440122255555, 36.181851348087825]]},
#   'properties': {'fromStopId': 'BUC23AWN',
#    'fromStopName': 'Buchanan St & 23rd Ave N Wb',
#    'toStopId': '23ASEINF',
#    'toStopName': '23rd Ave N & Seifried St Nb',
#    'pathLengthMeters': 23.576,
#    'averageTravelSeconds': 2.15991,
#    'averageTravelSpeed': 10.915269617715554,
#    'maxSecs': 5.752,
#    'percent90Secs': 2.552,
#    'percent80Secs': 2.231,
#    'percent70Secs': 2.168,
#    'medianSecs': 2.017,
#    'percent30Secs': 1.894,
#    'percent10Secs': 1.698,
#    'minSecs': 1.55}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81440122255555, 36.181851348087825],
#     [-86.81437600338322, 36.18206239274045]]},
#   'properties': {'fromStopId': 'BUC23AWN',
#    'fromStopName': 'Buchanan St & 23rd Ave N Wb',
#    'toStopId': '23ASEINF',
#    'toStopName': '23rd Ave N & Seifried St Nb',
#    'pathLengthMeters': 23.576,
#    'averageTravelSeconds': 2.177061,
#    'averageTravelSpeed': 10.829278554895797,
#    'maxSecs': 5.508,
#    'percent90Secs': 2.805,
#    'percent80Secs': 2.301,
#    'percent70Secs': 2.168,
#    'medianSecs': 2.0105,
#    'percent30Secs': 1.893,
#    'percent10Secs': 1.696,
#    'minSecs': 1.55}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82498665722785, 36.1900232834773],
#     [-86.82521347347685, 36.19015332479339]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'HAMHYDWN',
#    'toStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'pathLengthMeters': 24.968,
#    'averageTravelSeconds': 1.461333,
#    'averageTravelSpeed': 17.08577032065929,
#    'maxSecs': 2.152,
#    'percent90Secs': 1.922,
#    'percent80Secs': 1.563,
#    'percent70Secs': 1.519,
#    'medianSecs': 1.461,
#    'percent30Secs': 1.351,
#    'percent10Secs': 1.155,
#    'minSecs': 1.135}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83224091575445, 36.209704818399594],
#     [-86.83245568976912, 36.209562849135665]]},
#   'properties': {'fromStopId': 'WHATUCWM',
#    'fromStopName': 'W Hamilton Rd & Tucker Rd Wb',
#    'toStopId': 'WHAHAYEN',
#    'toStopName': 'W Hamilton Ave & Haynes Pk Eb',
#    'pathLengthMeters': 24.91,
#    'averageTravelSeconds': 2.205923,
#    'averageTravelSpeed': 11.292325253419998,
#    'maxSecs': 3.149,
#    'percent90Secs': 3.112,
#    'percent80Secs': 2.859,
#    'percent70Secs': 2.38,
#    'medianSecs': 2.073,
#    'percent30Secs': 1.87,
#    'percent10Secs': 1.544,
#    'minSecs': 1.458}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8254105461375, 36.190269064029074],
#     [-86.82563566212058, 36.19039850571934]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'CLACLINN',
#    'toStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'pathLengthMeters': 24.805,
#    'averageTravelSeconds': 1.463333,
#    'averageTravelSpeed': 16.95102891822982,
#    'maxSecs': 1.807,
#    'percent90Secs': 1.779,
#    'percent80Secs': 1.636,
#    'percent70Secs': 1.517,
#    'medianSecs': 1.461,
#    'percent30Secs': 1.39,
#    'percent10Secs': 1.172,
#    'minSecs': 1.133}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83918879153948, 36.21010483384208],
#     [-86.83923817244042, 36.20990731023835]]},
#   'properties': {'fromStopId': 'FAICLAEN',
#    'fromStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'toStopId': 'CLAFAISF',
#    'toStopName': 'Clarksville Pike & Fairview Dr Sb',
#    'pathLengthMeters': 22.406,
#    'averageTravelSeconds': 2.361625,
#    'averageTravelSpeed': 9.487535065897422,
#    'maxSecs': 3.442,
#    'percent90Secs': 3.442,
#    'percent80Secs': 2.629,
#    'percent70Secs': 2.424,
#    'medianSecs': 2.3235,
#    'percent30Secs': 2.103,
#    'percent10Secs': 1.861,
#    'minSecs': 1.861}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8237701797618, 36.210349036001375],
#     [-86.8238579738349, 36.21055187058408]]},
#   'properties': {'fromStopId': 'STOTUCWN',
#    'fromStopName': 'Stokers Ln & Tucker Rd Wb',
#    'toStopId': 'TUCWHANN',
#    'toStopName': 'Tucker Rd & W Hamilton Rd Nb',
#    'pathLengthMeters': 23.89,
#    'averageTravelSeconds': 3.548923,
#    'averageTravelSpeed': 6.73161970547121,
#    'maxSecs': 6.182,
#    'percent90Secs': 5.659,
#    'percent80Secs': 4.822,
#    'percent70Secs': 4.292,
#    'medianSecs': 3.275,
#    'percent30Secs': 2.502,
#    'percent10Secs': 2.144,
#    'minSecs': 2.041}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.80490391869353, 36.180361237752926],
#     [-86.80517087804027, 36.1803418566294]]},
#   'properties': {'fromStopId': 'BUC11AWF',
#    'fromStopName': 'Buchanan St & 11th Ave N Wb',
#    'toStopId': 'BUC15AWN',
#    'toStopName': 'Buchanan St & 15th Ave N Wb',
#    'pathLengthMeters': 24.057,
#    'averageTravelSeconds': 2.548618,
#    'averageTravelSpeed': 9.43923334136383,
#    'maxSecs': 12.65,
#    'percent90Secs': 3.573,
#    'percent80Secs': 2.525,
#    'percent70Secs': 2.351,
#    'medianSecs': 2.1035,
#    'percent30Secs': 1.767,
#    'percent10Secs': 1.601,
#    'minSecs': 1.281}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84363450078808, 36.211774246124165],
#     [-86.84336854972544, 36.21172873578189]]},
#   'properties': {'fromStopId': 'TIMFAISN',
#    'fromStopName': 'Timothy Dr & Fairview Dr Sb',
#    'toStopId': 'FAICLAEN',
#    'toStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'pathLengthMeters': 24.391,
#    'averageTravelSeconds': 2.224154,
#    'averageTravelSpeed': 10.966416893794223,
#    'maxSecs': 3.075,
#    'percent90Secs': 2.943,
#    'percent80Secs': 2.629,
#    'percent70Secs': 2.522,
#    'medianSecs': 2.15,
#    'percent30Secs': 1.909,
#    'percent10Secs': 1.598,
#    'minSecs': 1.573}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81095, 36.18011],
#     [-86.81121502804822, 36.180120754761376]]},
#   'properties': {'fromStopId': 'BUCDBTWN',
#    'fromStopName': 'Buchanan St & Dr D B Todd Jr Blvd Wb',
#    'toStopId': 'BUC23AWN',
#    'toStopName': 'Buchanan St & 23rd Ave N Wb',
#    'pathLengthMeters': 23.817,
#    'averageTravelSeconds': 4.266986,
#    'averageTravelSpeed': 5.5816916202677955,
#    'maxSecs': 11.208,
#    'percent90Secs': 7.805,
#    'percent80Secs': 6.221,
#    'percent70Secs': 4.75,
#    'medianSecs': 3.5515,
#    'percent30Secs': 2.808,
#    'percent10Secs': 2.251,
#    'minSecs': 1.736}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8431025986628, 36.21168322543962],
#     [-86.84283664760017, 36.21163771509735]]},
#   'properties': {'fromStopId': 'TIMFAISN',
#    'fromStopName': 'Timothy Dr & Fairview Dr Sb',
#    'toStopId': 'FAICLAEN',
#    'toStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'pathLengthMeters': 24.391,
#    'averageTravelSeconds': 2.217385,
#    'averageTravelSpeed': 10.999894019306524,
#    'maxSecs': 3.474,
#    'percent90Secs': 3.468,
#    'percent80Secs': 2.772,
#    'percent70Secs': 2.487,
#    'medianSecs': 1.887,
#    'percent30Secs': 1.851,
#    'percent10Secs': 1.529,
#    'minSecs': 1.459}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83637344022574, 36.19429325175842],
#     [-86.83660567237101, 36.194401139132985]]},
#   'properties': {'fromStopId': 'HAMHYDWN',
#    'fromStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'toStopId': 'JOHASHWF',
#    'toStopName': 'John Mallette Dr & Ashton Ave Wb',
#    'pathLengthMeters': 24.046,
#    'averageTravelSeconds': 2.742,
#    'averageTravelSpeed': 8.769511305616339,
#    'maxSecs': 3.6,
#    'percent90Secs': 3.6,
#    'percent80Secs': 3.6,
#    'percent70Secs': 3.6,
#    'medianSecs': 2.742,
#    'percent30Secs': 1.884,
#    'percent10Secs': 1.884,
#    'minSecs': 1.884}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83378185617293, 36.21097676389108],
#     [-86.83379124944368, 36.21118811248282]]},
#   'properties': {'fromStopId': 'HAYEVENN',
#    'fromStopName': 'Haynes Park Dr & Eve Cr Nb',
#    'toStopId': 'HAYEFANN',
#    'toStopName': 'Haynes Park Dr & Fairview Dr Nb',
#    'pathLengthMeters': 23.516,
#    'averageTravelSeconds': 2.917769,
#    'averageTravelSpeed': 8.059582509787443,
#    'maxSecs': 4.662,
#    'percent90Secs': 4.222,
#    'percent80Secs': 3.439,
#    'percent70Secs': 3.364,
#    'medianSecs': 2.939,
#    'percent30Secs': 2.415,
#    'percent10Secs': 1.943,
#    'minSecs': 1.739}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84452488386358, 36.217707440369416],
#     [-86.84478586063629, 36.2176809284433]]},
#   'properties': {'fromStopId': 'KINTEMWF',
#    'fromStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'toStopId': 'CRECRESN',
#    'toStopName': 'Creekwood & Creekland Ct Sb',
#    'pathLengthMeters': 23.597,
#    'averageTravelSeconds': 1.626846,
#    'averageTravelSpeed': 14.504753369403128,
#    'maxSecs': 2.201,
#    'percent90Secs': 2.093,
#    'percent80Secs': 1.901,
#    'percent70Secs': 1.88,
#    'medianSecs': 1.504,
#    'percent30Secs': 1.429,
#    'percent10Secs': 1.215,
#    'minSecs': 1.16}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82810265870404, 36.193355809255436],
#     [-86.82795021160538, 36.19352107900725]]},
#   'properties': {'fromStopId': 'CLSFCLK',
#    'fromStopName': 'Cliff Dr Past Clarksville Hwy',
#    'toStopId': 'CLICLANM',
#    'toStopName': 'Cliff Dr & Clarksville Pike Nb',
#    'pathLengthMeters': 22.91,
#    'averageTravelSeconds': 2.3371880000000003,
#    'averageTravelSpeed': 9.802377900280165,
#    'maxSecs': 3.402,
#    'percent90Secs': 3.329,
#    'percent80Secs': 2.855,
#    'percent70Secs': 2.52,
#    'medianSecs': 2.2685,
#    'percent30Secs': 2.027,
#    'percent10Secs': 1.575,
#    'minSecs': 1.537}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78992945567869, 36.171064361503205],
#     [-86.7900576982918, 36.171258421753734]]},
#   'properties': {'fromStopId': '8A9ANM',
#    'fromStopName': '8th Ave N & 9th Ave N Nb',
#    'toStopId': '8AJEFNF',
#    'toStopName': '8th Ave N & Jefferson St Nb',
#    'pathLengthMeters': 24.457,
#    'averageTravelSeconds': 2.070071,
#    'averageTravelSpeed': 11.81457061134618,
#    'maxSecs': 5.902,
#    'percent90Secs': 2.743,
#    'percent80Secs': 2.474,
#    'percent70Secs': 2.273,
#    'medianSecs': 1.974,
#    'percent30Secs': 1.684,
#    'percent10Secs': 1.397,
#    'minSecs': 1.284}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82453302472986, 36.18976320084512],
#     [-86.82475984097886, 36.18989324216121]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'HAMHYDWN',
#    'toStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'pathLengthMeters': 24.968,
#    'averageTravelSeconds': 1.467,
#    'averageTravelSpeed': 17.019768234492158,
#    'maxSecs': 2.152,
#    'percent90Secs': 1.922,
#    'percent80Secs': 1.56,
#    'percent70Secs': 1.526,
#    'medianSecs': 1.459,
#    'percent30Secs': 1.353,
#    'percent10Secs': 1.155,
#    'minSecs': 1.135}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81445166090019, 36.18142925878257],
#     [-86.81442644172787, 36.181640303435195]]},
#   'properties': {'fromStopId': 'BUC23AWN',
#    'fromStopName': 'Buchanan St & 23rd Ave N Wb',
#    'toStopId': '23ASEINF',
#    'toStopName': '23rd Ave N & Seifried St Nb',
#    'pathLengthMeters': 23.576,
#    'averageTravelSeconds': 2.144871,
#    'averageTravelSpeed': 10.991803236651528,
#    'maxSecs': 5.752,
#    'percent90Secs': 2.514,
#    'percent80Secs': 2.375,
#    'percent70Secs': 2.213,
#    'medianSecs': 2.05,
#    'percent30Secs': 1.9,
#    'percent10Secs': 1.703,
#    'minSecs': 1.55}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83245568976912, 36.209562849135665],
#     [-86.8326704637838, 36.20942087987173]]},
#   'properties': {'fromStopId': 'WHATUCWM',
#    'fromStopName': 'W Hamilton Rd & Tucker Rd Wb',
#    'toStopId': 'WHAHAYEN',
#    'toStopName': 'W Hamilton Ave & Haynes Pk Eb',
#    'pathLengthMeters': 24.91,
#    'averageTravelSeconds': 2.2382310000000003,
#    'averageTravelSpeed': 11.129324899887454,
#    'maxSecs': 3.147,
#    'percent90Secs': 3.111,
#    'percent80Secs': 2.925,
#    'percent70Secs': 2.38,
#    'medianSecs': 2.178,
#    'percent30Secs': 1.877,
#    'percent10Secs': 1.544,
#    'minSecs': 1.458}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82563566212058, 36.19039850571934],
#     [-86.82586077810365, 36.1905279474096]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'CLACLINN',
#    'toStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'pathLengthMeters': 24.805,
#    'averageTravelSeconds': 1.493762,
#    'averageTravelSpeed': 16.605724338950917,
#    'maxSecs': 2.062,
#    'percent90Secs': 1.784,
#    'percent80Secs': 1.659,
#    'percent70Secs': 1.558,
#    'medianSecs': 1.464,
#    'percent30Secs': 1.441,
#    'percent10Secs': 1.172,
#    'minSecs': 1.133}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84426390709086, 36.21773395229553],
#     [-86.84452488386358, 36.217707440369416]]},
#   'properties': {'fromStopId': 'KINTEMWF',
#    'fromStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'toStopId': 'CRECRESN',
#    'toStopName': 'Creekwood & Creekland Ct Sb',
#    'pathLengthMeters': 23.597,
#    'averageTravelSeconds': 1.614846,
#    'averageTravelSpeed': 14.612538904638585,
#    'maxSecs': 2.045,
#    'percent90Secs': 1.999,
#    'percent80Secs': 1.901,
#    'percent70Secs': 1.88,
#    'medianSecs': 1.504,
#    'percent30Secs': 1.429,
#    'percent10Secs': 1.215,
#    'minSecs': 1.16}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82363, 36.21023],
#     [-86.8237701797618, 36.210349036001375]]},
#   'properties': {'fromStopId': 'STOTUCWN',
#    'fromStopName': 'Stokers Ln & Tucker Rd Wb',
#    'toStopId': 'TUCWHANN',
#    'toStopName': 'Tucker Rd & W Hamilton Rd Nb',
#    'pathLengthMeters': 23.89,
#    'averageTravelSeconds': 5.180769000000001,
#    'averageTravelSpeed': 4.6112845409629335,
#    'maxSecs': 18.115,
#    'percent90Secs': 13.305,
#    'percent80Secs': 5.117,
#    'percent70Secs': 4.572,
#    'medianSecs': 4.307,
#    'percent30Secs': 3.838,
#    'percent10Secs': 2.59,
#    'minSecs': 2.417}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81121502804822, 36.180120754761376],
#     [-86.81148005609643, 36.18013150952275]]},
#   'properties': {'fromStopId': 'BUCDBTWN',
#    'fromStopName': 'Buchanan St & Dr D B Todd Jr Blvd Wb',
#    'toStopId': 'BUC23AWN',
#    'toStopName': 'Buchanan St & 23rd Ave N Wb',
#    'pathLengthMeters': 23.817,
#    'averageTravelSeconds': 3.503686,
#    'averageTravelSpeed': 6.797698195557478,
#    'maxSecs': 7.802,
#    'percent90Secs': 5.562,
#    'percent80Secs': 4.615,
#    'percent70Secs': 3.97,
#    'medianSecs': 3.288,
#    'percent30Secs': 2.553,
#    'percent10Secs': 2.094,
#    'minSecs': 1.699}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83913941063855, 36.21030235744581],
#     [-86.83918879153948, 36.21010483384208]]},
#   'properties': {'fromStopId': 'FAICLAEN',
#    'fromStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'toStopId': 'CLAFAISF',
#    'toStopName': 'Clarksville Pike & Fairview Dr Sb',
#    'pathLengthMeters': 22.406,
#    'averageTravelSeconds': 2.480875,
#    'averageTravelSpeed': 9.031490905426512,
#    'maxSecs': 3.442,
#    'percent90Secs': 3.442,
#    'percent80Secs': 3.39,
#    'percent70Secs': 2.711,
#    'medianSecs': 2.3235,
#    'percent30Secs': 2.103,
#    'percent10Secs': 1.861,
#    'minSecs': 1.861}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.80517087804027, 36.1803418566294],
#     [-86.80543783738703, 36.18032247550586]]},
#   'properties': {'fromStopId': 'BUC11AWF',
#    'fromStopName': 'Buchanan St & 11th Ave N Wb',
#    'toStopId': 'BUC15AWN',
#    'toStopName': 'Buchanan St & 15th Ave N Wb',
#    'pathLengthMeters': 24.057,
#    'averageTravelSeconds': 3.0444850000000003,
#    'averageTravelSpeed': 7.901829044978049,
#    'maxSecs': 17.958,
#    'percent90Secs': 4.965,
#    'percent80Secs': 2.556,
#    'percent70Secs': 2.301,
#    'medianSecs': 2.0225,
#    'percent30Secs': 1.756,
#    'percent10Secs': 1.597,
#    'minSecs': 1.255}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82856, 36.19286],
#     [-86.82840755290134, 36.193025269751814]]},
#   'properties': {'fromStopId': 'CLSFCLK',
#    'fromStopName': 'Cliff Dr Past Clarksville Hwy',
#    'toStopId': 'CLICLANM',
#    'toStopName': 'Cliff Dr & Clarksville Pike Nb',
#    'pathLengthMeters': 22.91,
#    'averageTravelSeconds': 6.452875,
#    'averageTravelSpeed': 3.550355461712803,
#    'maxSecs': 47.968,
#    'percent90Secs': 20.902,
#    'percent80Secs': 7.03,
#    'percent70Secs': 3.543,
#    'medianSecs': 2.8245,
#    'percent30Secs': 2.562,
#    'percent10Secs': 2.194,
#    'minSecs': 2.018}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83614120808048, 36.19418536438384],
#     [-86.83637344022574, 36.19429325175842]]},
#   'properties': {'fromStopId': 'HAMHYDWN',
#    'fromStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'toStopId': 'JOHASHWF',
#    'toStopName': 'John Mallette Dr & Ashton Ave Wb',
#    'pathLengthMeters': 24.046,
#    'averageTravelSeconds': 2.742,
#    'averageTravelSpeed': 8.769511305616339,
#    'maxSecs': 3.6,
#    'percent90Secs': 3.6,
#    'percent80Secs': 3.6,
#    'percent70Secs': 3.6,
#    'medianSecs': 2.742,
#    'percent30Secs': 1.884,
#    'percent10Secs': 1.884,
#    'minSecs': 1.884}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82871182911568, 36.192677841366304],
#     [-86.82854884339558, 36.192851230430236]]},
#   'properties': {'fromStopId': 'CLACLINN',
#    'fromStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'toStopId': 'CLSFCLK',
#    'toStopName': 'Cliff Dr Past Clarksville Hwy',
#    'pathLengthMeters': 24.2,
#    'averageTravelSeconds': 16.693375,
#    'averageTravelSpeed': 1.449676892779321,
#    'maxSecs': 93.427,
#    'percent90Secs': 91.867,
#    'percent80Secs': 16.672,
#    'percent70Secs': 12.644,
#    'medianSecs': 3.514,
#    'percent30Secs': 2.864,
#    'percent10Secs': 2.504,
#    'minSecs': 2.415}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83377246290219, 36.21076541529935],
#     [-86.83378185617293, 36.21097676389108]]},
#   'properties': {'fromStopId': 'HAYEVENN',
#    'fromStopName': 'Haynes Park Dr & Eve Cr Nb',
#    'toStopId': 'HAYEFANN',
#    'toStopName': 'Haynes Park Dr & Fairview Dr Nb',
#    'pathLengthMeters': 23.516,
#    'averageTravelSeconds': 2.6732310000000004,
#    'averageTravelSpeed': 8.796845465281525,
#    'maxSecs': 3.536,
#    'percent90Secs': 3.467,
#    'percent80Secs': 3.362,
#    'percent70Secs': 3.086,
#    'medianSecs': 2.568,
#    'percent30Secs': 2.218,
#    'percent10Secs': 1.899,
#    'minSecs': 1.739}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84283664760017, 36.21163771509735],
#     [-86.84257069653752, 36.211592204755085]]},
#   'properties': {'fromStopId': 'TIMFAISN',
#    'fromStopName': 'Timothy Dr & Fairview Dr Sb',
#    'toStopId': 'FAICLAEN',
#    'toStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'pathLengthMeters': 24.391,
#    'averageTravelSeconds': 2.2769229999999996,
#    'averageTravelSpeed': 10.71226387541432,
#    'maxSecs': 3.503,
#    'percent90Secs': 3.491,
#    'percent80Secs': 3.029,
#    'percent70Secs': 2.606,
#    'medianSecs': 1.887,
#    'percent30Secs': 1.851,
#    'percent10Secs': 1.529,
#    'minSecs': 1.459}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84067005114231, 36.2038960700064],
#     [-86.84066669081567, 36.20367732914934]]},
#   'properties': {'fromStopId': 'CLAWHASN',
#    'fromStopName': 'Clarksville Pike & W. Hamilton Ave',
#    'toStopId': 'CLAABESN',
#    'toStopName': 'Clarksville Pike & Abernathy Rd Sb',
#    'pathLengthMeters': 24.416,
#    'averageTravelSeconds': 2.0095,
#    'averageTravelSpeed': 12.150286140831053,
#    'maxSecs': 2.267,
#    'percent90Secs': 2.267,
#    'percent80Secs': 2.26,
#    'percent70Secs': 2.239,
#    'medianSecs': 2.059,
#    'percent30Secs': 1.82,
#    'percent10Secs': 1.62,
#    'minSecs': 1.62}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78954472783934, 36.1704821807516],
#     [-86.78967297045246, 36.170676241002134]]},
#   'properties': {'fromStopId': '8A9ANM',
#    'fromStopName': '8th Ave N & 9th Ave N Nb',
#    'toStopId': '8AJEFNF',
#    'toStopName': '8th Ave N & Jefferson St Nb',
#    'pathLengthMeters': 24.457,
#    'averageTravelSeconds': 2.4181999999999997,
#    'averageTravelSpeed': 10.113720949466547,
#    'maxSecs': 7.483,
#    'percent90Secs': 4.654,
#    'percent80Secs': 2.978,
#    'percent70Secs': 2.543,
#    'medianSecs': 1.99,
#    'percent30Secs': 1.624,
#    'percent10Secs': 1.373,
#    'minSecs': 1.284}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8260858940867, 36.19065738909986],
#     [-86.82631101006977, 36.19078683079012]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'CLACLINN',
#    'toStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'pathLengthMeters': 24.805,
#    'averageTravelSeconds': 1.522381,
#    'averageTravelSpeed': 16.29355594952906,
#    'maxSecs': 2.062,
#    'percent90Secs': 1.786,
#    'percent80Secs': 1.68,
#    'percent70Secs': 1.626,
#    'medianSecs': 1.488,
#    'percent30Secs': 1.441,
#    'percent10Secs': 1.19,
#    'minSecs': 1.133}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81447688007252, 36.18121821412995],
#     [-86.81445166090019, 36.18142925878257]]},
#   'properties': {'fromStopId': 'BUC23AWN',
#    'fromStopName': 'Buchanan St & 23rd Ave N Wb',
#    'toStopId': '23ASEINF',
#    'toStopName': '23rd Ave N & Seifried St Nb',
#    'pathLengthMeters': 23.576,
#    'averageTravelSeconds': 2.168943,
#    'averageTravelSpeed': 10.869810778798705,
#    'maxSecs': 4.337,
#    'percent90Secs': 2.571,
#    'percent80Secs': 2.436,
#    'percent70Secs': 2.245,
#    'medianSecs': 2.096,
#    'percent30Secs': 1.978,
#    'percent10Secs': 1.8,
#    'minSecs': 1.56}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82544028972583, 36.19028336610948],
#     [-86.82566710597483, 36.190413407425574]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'HAMHYDWN',
#    'toStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'pathLengthMeters': 24.968,
#    'averageTravelSeconds': 1.447857,
#    'averageTravelSpeed': 17.244796965446174,
#    'maxSecs': 2.152,
#    'percent90Secs': 1.668,
#    'percent80Secs': 1.579,
#    'percent70Secs': 1.543,
#    'medianSecs': 1.461,
#    'percent30Secs': 1.342,
#    'percent10Secs': 1.155,
#    'minSecs': 1.118}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83181136772512, 36.20998875692746],
#     [-86.83202614173979, 36.20984678766353]]},
#   'properties': {'fromStopId': 'WHATUCWM',
#    'fromStopName': 'W Hamilton Rd & Tucker Rd Wb',
#    'toStopId': 'WHAHAYEN',
#    'toStopName': 'W Hamilton Ave & Haynes Pk Eb',
#    'pathLengthMeters': 24.91,
#    'averageTravelSeconds': 3.519692,
#    'averageTravelSpeed': 7.077323811288033,
#    'maxSecs': 23.516,
#    'percent90Secs': 14.98,
#    'percent80Secs': 2.093,
#    'percent70Secs': 2.033,
#    'medianSecs': 1.877,
#    'percent30Secs': 1.74,
#    'percent10Secs': 1.529,
#    'minSecs': 1.458}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82586077810365, 36.1905279474096],
#     [-86.8260858940867, 36.19065738909986]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'CLACLINN',
#    'toStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'pathLengthMeters': 24.805,
#    'averageTravelSeconds': 1.518286,
#    'averageTravelSpeed': 16.337501630127658,
#    'maxSecs': 2.062,
#    'percent90Secs': 1.786,
#    'percent80Secs': 1.679,
#    'percent70Secs': 1.621,
#    'medianSecs': 1.488,
#    'percent30Secs': 1.441,
#    'percent10Secs': 1.19,
#    'minSecs': 1.133}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83909002973762, 36.210499881049536],
#     [-86.83913941063855, 36.21030235744581]]},
#   'properties': {'fromStopId': 'FAICLAEN',
#    'fromStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'toStopId': 'CLAFAISF',
#    'toStopName': 'Clarksville Pike & Fairview Dr Sb',
#    'pathLengthMeters': 22.406,
#    'averageTravelSeconds': 2.711,
#    'averageTravelSpeed': 8.264846919955735,
#    'maxSecs': 4.379,
#    'percent90Secs': 4.379,
#    'percent80Secs': 3.585,
#    'percent70Secs': 3.314,
#    'medianSecs': 2.342,
#    'percent30Secs': 2.103,
#    'percent10Secs': 1.861,
#    'minSecs': 1.861}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84400293031815, 36.21776046422165],
#     [-86.84426390709086, 36.21773395229553]]},
#   'properties': {'fromStopId': 'KINTEMWF',
#    'fromStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'toStopId': 'CRECRESN',
#    'toStopName': 'Creekwood & Creekland Ct Sb',
#    'pathLengthMeters': 23.597,
#    'averageTravelSeconds': 1.582615,
#    'averageTravelSpeed': 14.910132912932077,
#    'maxSecs': 1.892,
#    'percent90Secs': 1.878,
#    'percent80Secs': 1.836,
#    'percent70Secs': 1.808,
#    'medianSecs': 1.504,
#    'percent30Secs': 1.429,
#    'percent10Secs': 1.215,
#    'minSecs': 1.16}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78492464287032, 36.16870620747944],
#     [-86.78517614408902, 36.16863834207122]]},
#   'properties': {'fromStopId': '5AVGAYNN',
#    'fromStopName': '5AVGAYNN (stop name not available)',
#    'toStopId': 'JAM6AWN',
#    'toStopName': 'James Robertson Pkwy & 6th Ave N Wb',
#    'pathLengthMeters': 23.804,
#    'averageTravelSeconds': 3.08323,
#    'averageTravelSpeed': 7.720474956458,
#    'maxSecs': 17.218,
#    'percent90Secs': 4.395,
#    'percent80Secs': 3.147,
#    'percent70Secs': 2.797,
#    'medianSecs': 2.4085,
#    'percent30Secs': 2.094,
#    'percent10Secs': 1.806,
#    'minSecs': 1.53}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.80543783738703, 36.18032247550586],
#     [-86.80570479673379, 36.180303094382325]]},
#   'properties': {'fromStopId': 'BUC11AWF',
#    'fromStopName': 'Buchanan St & 11th Ave N Wb',
#    'toStopId': 'BUC15AWN',
#    'toStopName': 'Buchanan St & 15th Ave N Wb',
#    'pathLengthMeters': 24.057,
#    'averageTravelSeconds': 2.215941,
#    'averageTravelSpeed': 10.856335976454247,
#    'maxSecs': 8.671,
#    'percent90Secs': 2.922,
#    'percent80Secs': 2.351,
#    'percent70Secs': 2.228,
#    'medianSecs': 2,
#    'percent30Secs': 1.756,
#    'percent10Secs': 1.575,
#    'minSecs': 1.255}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83590897593521, 36.19407747700927],
#     [-86.83614120808048, 36.19418536438384]]},
#   'properties': {'fromStopId': 'HAMHYDWN',
#    'fromStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'toStopId': 'JOHASHWF',
#    'toStopName': 'John Mallette Dr & Ashton Ave Wb',
#    'pathLengthMeters': 24.046,
#    'averageTravelSeconds': 2.742,
#    'averageTravelSpeed': 8.769511305616339,
#    'maxSecs': 3.6,
#    'percent90Secs': 3.6,
#    'percent80Secs': 3.6,
#    'percent70Secs': 3.6,
#    'medianSecs': 2.742,
#    'percent30Secs': 1.884,
#    'percent10Secs': 1.884,
#    'minSecs': 1.884}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82887481483579, 36.192504452302366],
#     [-86.82871182911568, 36.192677841366304]]},
#   'properties': {'fromStopId': 'CLACLINN',
#    'fromStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'toStopId': 'CLSFCLK',
#    'toStopName': 'Cliff Dr Past Clarksville Hwy',
#    'pathLengthMeters': 24.2,
#    'averageTravelSeconds': 3.446941,
#    'averageTravelSpeed': 7.020717790063712,
#    'maxSecs': 6.647,
#    'percent90Secs': 4.496,
#    'percent80Secs': 3.728,
#    'percent70Secs': 3.494,
#    'medianSecs': 3.415,
#    'percent30Secs': 2.944,
#    'percent10Secs': 2.642,
#    'minSecs': 2.415}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82840755290134, 36.193025269751814],
#     [-86.8282551058027, 36.193190539503625]]},
#   'properties': {'fromStopId': 'CLSFCLK',
#    'fromStopName': 'Cliff Dr Past Clarksville Hwy',
#    'toStopId': 'CLICLANM',
#    'toStopName': 'Cliff Dr & Clarksville Pike Nb',
#    'pathLengthMeters': 22.91,
#    'averageTravelSeconds': 2.983125,
#    'averageTravelSpeed': 7.679865912424052,
#    'maxSecs': 6.801,
#    'percent90Secs': 5.057,
#    'percent80Secs': 3.36,
#    'percent70Secs': 3.083,
#    'medianSecs': 2.6415,
#    'percent30Secs': 2.333,
#    'percent10Secs': 2.098,
#    'minSecs': 2.018}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84066669081567, 36.20367732914934],
#     [-86.84063838141061, 36.20345894231047]]},
#   'properties': {'fromStopId': 'CLAWHASN',
#    'fromStopName': 'Clarksville Pike & W. Hamilton Ave',
#    'toStopId': 'CLAABESN',
#    'toStopName': 'Clarksville Pike & Abernathy Rd Sb',
#    'pathLengthMeters': 24.416,
#    'averageTravelSeconds': 2.07175,
#    'averageTravelSpeed': 11.785205743936285,
#    'maxSecs': 2.267,
#    'percent90Secs': 2.267,
#    'percent80Secs': 2.267,
#    'percent70Secs': 2.258,
#    'medianSecs': 2.1085,
#    'percent30Secs': 1.886,
#    'percent10Secs': 1.803,
#    'minSecs': 1.803}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84257069653752, 36.211592204755085],
#     [-86.84230474547489, 36.21154669441281]]},
#   'properties': {'fromStopId': 'TIMFAISN',
#    'fromStopName': 'Timothy Dr & Fairview Dr Sb',
#    'toStopId': 'FAICLAEN',
#    'toStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'pathLengthMeters': 24.391,
#    'averageTravelSeconds': 2.327154,
#    'averageTravelSpeed': 10.48104250943427,
#    'maxSecs': 3.503,
#    'percent90Secs': 3.491,
#    'percent80Secs': 3.31,
#    'percent70Secs': 2.606,
#    'medianSecs': 2.076,
#    'percent30Secs': 1.851,
#    'percent10Secs': 1.529,
#    'minSecs': 1.459}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83381, 36.21161],
#     [-86.83381887031835, 36.211810690952625]]},
#   'properties': {'fromStopId': 'HAYEFANN',
#    'fromStopName': 'Haynes Park Dr & Fairview Dr Nb',
#    'toStopId': 'HAYCHANN',
#    'toStopName': 'Haynes Park Dr & Charles Ct Nb',
#    'pathLengthMeters': 22.33,
#    'averageTravelSeconds': 4.072615,
#    'averageTravelSpeed': 5.482963648663082,
#    'maxSecs': 12.544,
#    'percent90Secs': 9.632,
#    'percent80Secs': 4.817,
#    'percent70Secs': 3.764,
#    'medianSecs': 3.238,
#    'percent30Secs': 2.961,
#    'percent10Secs': 2.187,
#    'minSecs': 1.894}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83379128622921, 36.21055491461574],
#     [-86.83377246290219, 36.21076541529935]]},
#   'properties': {'fromStopId': 'HAYEVENN',
#    'fromStopName': 'Haynes Park Dr & Eve Cr Nb',
#    'toStopId': 'HAYEFANN',
#    'toStopName': 'Haynes Park Dr & Fairview Dr Nb',
#    'pathLengthMeters': 23.516,
#    'averageTravelSeconds': 2.4357689999999996,
#    'averageTravelSpeed': 9.654445885467794,
#    'maxSecs': 2.974,
#    'percent90Secs': 2.958,
#    'percent80Secs': 2.882,
#    'percent70Secs': 2.773,
#    'medianSecs': 2.29,
#    'percent30Secs': 2.208,
#    'percent10Secs': 1.899,
#    'minSecs': 1.739}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82631101006977, 36.19078683079012],
#     [-86.82653612605283, 36.19091627248038]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'CLACLINN',
#    'toStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'pathLengthMeters': 24.805,
#    'averageTravelSeconds': 1.5283330000000002,
#    'averageTravelSpeed': 16.230101685954565,
#    'maxSecs': 2.062,
#    'percent90Secs': 1.786,
#    'percent80Secs': 1.68,
#    'percent70Secs': 1.636,
#    'medianSecs': 1.511,
#    'percent30Secs': 1.441,
#    'percent10Secs': 1.19,
#    'minSecs': 1.133}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78967297045246, 36.170676241002134],
#     [-86.78980121306557, 36.17087030125267]]},
#   'properties': {'fromStopId': '8A9ANM',
#    'fromStopName': '8th Ave N & 9th Ave N Nb',
#    'toStopId': '8AJEFNF',
#    'toStopName': '8th Ave N & Jefferson St Nb',
#    'pathLengthMeters': 24.457,
#    'averageTravelSeconds': 2.1051860000000002,
#    'averageTravelSpeed': 11.617500781403638,
#    'maxSecs': 4.216,
#    'percent90Secs': 3.121,
#    'percent80Secs': 2.592,
#    'percent70Secs': 2.293,
#    'medianSecs': 2.0005,
#    'percent30Secs': 1.624,
#    'percent10Secs': 1.391,
#    'minSecs': 1.284}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81450209924485, 36.18100716947732],
#     [-86.81447688007252, 36.18121821412995]]},
#   'properties': {'fromStopId': 'BUC23AWN',
#    'fromStopName': 'Buchanan St & 23rd Ave N Wb',
#    'toStopId': '23ASEINF',
#    'toStopName': '23rd Ave N & Seifried St Nb',
#    'pathLengthMeters': 23.576,
#    'averageTravelSeconds': 2.351686,
#    'averageTravelSpeed': 10.02514791515534,
#    'maxSecs': 3.073,
#    'percent90Secs': 2.91,
#    'percent80Secs': 2.781,
#    'percent70Secs': 2.697,
#    'medianSecs': 2.261,
#    'percent30Secs': 2.04,
#    'percent10Secs': 1.852,
#    'minSecs': 1.56}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83202614173979, 36.20984678766353],
#     [-86.83224091575445, 36.209704818399594]]},
#   'properties': {'fromStopId': 'WHATUCWM',
#    'fromStopName': 'W Hamilton Rd & Tucker Rd Wb',
#    'toStopId': 'WHAHAYEN',
#    'toStopName': 'W Hamilton Ave & Haynes Pk Eb',
#    'pathLengthMeters': 24.91,
#    'averageTravelSeconds': 2.373231,
#    'averageTravelSpeed': 10.496239093455292,
#    'maxSecs': 7.884,
#    'percent90Secs': 5.653,
#    'percent80Secs': 2.201,
#    'percent70Secs': 2.066,
#    'medianSecs': 1.885,
#    'percent30Secs': 1.831,
#    'percent10Secs': 1.544,
#    'minSecs': 1.458}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82521347347685, 36.19015332479339],
#     [-86.82544028972583, 36.19028336610948]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'HAMHYDWN',
#    'toStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'pathLengthMeters': 24.968,
#    'averageTravelSeconds': 1.47,
#    'averageTravelSpeed': 16.985034013605443,
#    'maxSecs': 2.152,
#    'percent90Secs': 1.867,
#    'percent80Secs': 1.585,
#    'percent70Secs': 1.555,
#    'medianSecs': 1.461,
#    'percent30Secs': 1.351,
#    'percent10Secs': 1.155,
#    'minSecs': 1.136}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83904064883669, 36.21069740465327],
#     [-86.83909002973762, 36.210499881049536]]},
#   'properties': {'fromStopId': 'FAICLAEN',
#    'fromStopName': 'Fairview Dr & Clarksville Pike Eb',
#    'toStopId': 'CLAFAISF',
#    'toStopName': 'Clarksville Pike & Fairview Dr Sb',
#    'pathLengthMeters': 22.406,
#    'averageTravelSeconds': 5.65225,
#    'averageTravelSpeed': 3.964085098854438,
#    'maxSecs': 16.997,
#    'percent90Secs': 16.997,
#    'percent80Secs': 8.652,
#    'percent70Secs': 5.55,
#    'medianSecs': 4.53,
#    'percent30Secs': 3.027,
#    'percent10Secs': 1.907,
#    'minSecs': 1.907}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.80570479673379, 36.180303094382325],
#     [-86.80597175608055, 36.18028371325879]]},
#   'properties': {'fromStopId': 'BUC11AWF',
#    'fromStopName': 'Buchanan St & 11th Ave N Wb',
#    'toStopId': 'BUC15AWN',
#    'toStopName': 'Buchanan St & 15th Ave N Wb',
#    'pathLengthMeters': 24.057,
#    'averageTravelSeconds': 2.0576619999999997,
#    'averageTravelSpeed': 11.69142453911284,
#    'maxSecs': 4.812,
#    'percent90Secs': 2.822,
#    'percent80Secs': 2.261,
#    'percent70Secs': 2.157,
#    'medianSecs': 1.9775,
#    'percent30Secs': 1.744,
#    'percent10Secs': 1.575,
#    'minSecs': 1.255}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84374195354543, 36.21778697614777],
#     [-86.84400293031815, 36.21776046422165]]},
#   'properties': {'fromStopId': 'KINTEMWF',
#    'fromStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'toStopId': 'CRECRESN',
#    'toStopName': 'Creekwood & Creekland Ct Sb',
#    'pathLengthMeters': 23.597,
#    'averageTravelSeconds': 1.506231,
#    'averageTravelSpeed': 15.666255707125933,
#    'maxSecs': 1.816,
#    'percent90Secs': 1.81,
#    'percent80Secs': 1.675,
#    'percent70Secs': 1.609,
#    'medianSecs': 1.493,
#    'percent30Secs': 1.423,
#    'percent10Secs': 1.215,
#    'minSecs': 1.16}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78467314165164, 36.16877407288766],
#     [-86.78492464287032, 36.16870620747944]]},
#   'properties': {'fromStopId': '5AVGAYNN',
#    'fromStopName': '5AVGAYNN (stop name not available)',
#    'toStopId': 'JAM6AWN',
#    'toStopName': 'James Robertson Pkwy & 6th Ave N Wb',
#    'pathLengthMeters': 23.804,
#    'averageTravelSeconds': 3.1148290000000003,
#    'averageTravelSpeed': 7.6421530684348955,
#    'maxSecs': 17.218,
#    'percent90Secs': 4.59,
#    'percent80Secs': 3.207,
#    'percent70Secs': 2.926,
#    'medianSecs': 2.492,
#    'percent30Secs': 2.196,
#    'percent10Secs': 1.819,
#    'minSecs': 1.53}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84582976772717, 36.21757488073883],
#     [-86.84609074449988, 36.21754836881271]]},
#   'properties': {'fromStopId': 'KINTEMWF',
#    'fromStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'toStopId': 'CRECRESN',
#    'toStopName': 'Creekwood & Creekland Ct Sb',
#    'pathLengthMeters': 23.597,
#    'averageTravelSeconds': 2.886615,
#    'averageTravelSpeed': 8.17462668211729,
#    'maxSecs': 6.124,
#    'percent90Secs': 5.199,
#    'percent80Secs': 3.337,
#    'percent70Secs': 3.184,
#    'medianSecs': 2.486,
#    'percent30Secs': 2.16,
#    'percent10Secs': 1.856,
#    'minSecs': 1.831}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8289961811439, 36.19233601936707],
#     [-86.82887481483579, 36.192504452302366]]},
#   'properties': {'fromStopId': 'CLACLINN',
#    'fromStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'toStopId': 'CLSFCLK',
#    'toStopName': 'Cliff Dr Past Clarksville Hwy',
#    'pathLengthMeters': 24.2,
#    'averageTravelSeconds': 3.5812779999999997,
#    'averageTravelSpeed': 6.757364270520189,
#    'maxSecs': 6.036,
#    'percent90Secs': 5.069,
#    'percent80Secs': 4.228,
#    'percent70Secs': 3.782,
#    'medianSecs': 3.4165,
#    'percent30Secs': 2.969,
#    'percent10Secs': 2.665,
#    'minSecs': 2.358}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83382013712114, 36.210344715260234],
#     [-86.83379128622921, 36.21055491461574]]},
#   'properties': {'fromStopId': 'HAYEVENN',
#    'fromStopName': 'Haynes Park Dr & Eve Cr Nb',
#    'toStopId': 'HAYEFANN',
#    'toStopName': 'Haynes Park Dr & Fairview Dr Nb',
#    'pathLengthMeters': 23.516,
#    'averageTravelSeconds': 2.252846,
#    'averageTravelSpeed': 10.438352199839668,
#    'maxSecs': 2.824,
#    'percent90Secs': 2.722,
#    'percent80Secs': 2.498,
#    'percent70Secs': 2.389,
#    'medianSecs': 2.248,
#    'percent30Secs': 2.194,
#    'percent10Secs': 1.699,
#    'minSecs': 1.672}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84301, 36.18443],
#     [-86.84318371255601, 36.18426254735593]]},
#   'properties': {'fromStopId': 'COUPANWN',
#    'fromStopName': 'County Hospital Rd & Panorama Dr Wb',
#    'toStopId': 'COUHOSWN',
#    'toStopName': 'County Hospital Rd & Hospital Ln Wb',
#    'pathLengthMeters': 24.285,
#    'averageTravelSeconds': 17.278833,
#    'averageTravelSpeed': 1.4054768629339724,
#    'maxSecs': 145.282,
#    'percent90Secs': 62.971,
#    'percent80Secs': 13.309,
#    'percent70Secs': 12.467,
#    'medianSecs': 5.902,
#    'percent30Secs': 3.495,
#    'percent10Secs': 2.673,
#    'minSecs': 2.471}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84063249886253, 36.20433417993707],
#     [-86.84065127500243, 36.204115124971736]]},
#   'properties': {'fromStopId': 'CLAWHASN',
#    'fromStopName': 'Clarksville Pike & W. Hamilton Ave',
#    'toStopId': 'CLAABESN',
#    'toStopName': 'Clarksville Pike & Abernathy Rd Sb',
#    'pathLengthMeters': 24.416,
#    'averageTravelSeconds': 1.95,
#    'averageTravelSpeed': 12.521025641025641,
#    'maxSecs': 2.267,
#    'percent90Secs': 2.267,
#    'percent80Secs': 2.253,
#    'percent70Secs': 2.18,
#    'medianSecs': 2.059,
#    'percent30Secs': 1.748,
#    'percent10Secs': 1.392,
#    'minSecs': 1.392}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.840230578154, 36.19321133653869],
#     [-86.84010458237455, 36.193023842819265]]},
#   'properties': {'fromStopId': 'ELIHYDSN',
#    'fromStopName': 'Elizabeth Rd & Hydes Ferry Rd Sb',
#    'toStopId': 'HYDMANSF',
#    'toStopName': 'Hydes Ferry Rd & Manchester Ave Sb',
#    'pathLengthMeters': 23.717,
#    'averageTravelSeconds': 2.992,
#    'averageTravelSpeed': 7.926804812834225,
#    'maxSecs': 3.475,
#    'percent90Secs': 3.475,
#    'percent80Secs': 3.475,
#    'percent70Secs': 3.475,
#    'medianSecs': 2.992,
#    'percent30Secs': 2.509,
#    'percent10Secs': 2.509,
#    'minSecs': 2.509}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83381887031835, 36.211810690952625],
#     [-86.83382774063669, 36.21201138190525]]},
#   'properties': {'fromStopId': 'HAYEFANN',
#    'fromStopName': 'Haynes Park Dr & Fairview Dr Nb',
#    'toStopId': 'HAYCHANN',
#    'toStopName': 'Haynes Park Dr & Charles Ct Nb',
#    'pathLengthMeters': 22.33,
#    'averageTravelSeconds': 3.099692,
#    'averageTravelSpeed': 7.203941552902674,
#    'maxSecs': 5.474,
#    'percent90Secs': 4.718,
#    'percent80Secs': 3.392,
#    'percent70Secs': 3.316,
#    'medianSecs': 2.98,
#    'percent30Secs': 2.819,
#    'percent10Secs': 2.026,
#    'minSecs': 1.792}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78928824261311, 36.170094060250534],
#     [-86.78941648522623, 36.17028812050107]]},
#   'properties': {'fromStopId': '8A9ANM',
#    'fromStopName': '8th Ave N & 9th Ave N Nb',
#    'toStopId': '8AJEFNF',
#    'toStopName': '8th Ave N & Jefferson St Nb',
#    'pathLengthMeters': 24.457,
#    'averageTravelSeconds': 7.716848,
#    'averageTravelSpeed': 3.1692991749999484,
#    'maxSecs': 46.468,
#    'percent90Secs': 31.805,
#    'percent80Secs': 13.802,
#    'percent70Secs': 3.632,
#    'medianSecs': 2.0395,
#    'percent30Secs': 1.705,
#    'percent10Secs': 1.37,
#    'minSecs': 1.284}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83138181969579, 36.21027269545533],
#     [-86.83159659371046, 36.210130726191395]]},
#   'properties': {'fromStopId': 'WHATUCWM',
# ...
#    'averageTravelSpeed': 12.191471720258193,
#    'maxSecs': 4.402,
#    'percent90Secs': 3.094,
#    'percent80Secs': 2.454,
#    'percent70Secs': 2.108,
#    'medianSecs': 1.813,
#    'percent30Secs': 1.575,
#    'percent10Secs': 1.444,
#    'minSecs': 1.33}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83970262636981, 36.21822966473008],
#     [-86.8399736785673, 36.21819963679092]]},
#   'properties': {'fromStopId': 'KINCLAW',
#    'fromStopName': 'Kings Ln & Clarksville Pk Wb',
#    'toStopId': 'KINTEMWF',
#    'toStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'pathLengthMeters': 24.544,
#    'averageTravelSeconds': 1.638538,
#    'averageTravelSpeed': 14.979207073622948,
#    'maxSecs': 1.882,
#    'percent90Secs': 1.881,
#    'percent80Secs': 1.874,
#    'percent70Secs': 1.808,
#    'medianSecs': 1.659,
#    'percent30Secs': 1.463,
#    'percent10Secs': 1.374,
#    'minSecs': 1.346}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84460751167501, 36.21304680456288],
#     [-86.84460287335936, 36.21282648456968]]},
#   'properties': {'fromStopId': 'CRECRWSN',
#    'fromStopName': 'Creekwood & Creekway Ct Sb',
#    'toStopId': 'TIMFAISN',
#    'toStopName': 'Timothy Dr & Fairview Dr Sb',
#    'pathLengthMeters': 24.502,
#    'averageTravelSeconds': 2.736231,
#    'averageTravelSpeed': 8.95465331691659,
#    'maxSecs': 3.456,
#    'percent90Secs': 3.266,
#    'percent80Secs': 2.897,
#    'percent70Secs': 2.851,
#    'medianSecs': 2.708,
#    'percent30Secs': 2.604,
#    'percent10Secs': 2.367,
#    'minSecs': 2.326}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83806679590758, 36.18998519386137],
#     [-86.83793599488448, 36.189788992326704]]},
#   'properties': {'fromStopId': 'HYDMANSF',
#    'fromStopName': 'Hydes Ferry Rd & Manchester Ave Sb',
#    'toStopId': 'COUHYDWF',
#    'toStopName': 'County Hospital Rd & Hydes Ferry Rd',
#    'pathLengthMeters': 24.774,
#    'averageTravelSeconds': 3.4645,
#    'averageTravelSpeed': 7.150815413479578,
#    'maxSecs': 3.802,
#    'percent90Secs': 3.802,
#    'percent80Secs': 3.802,
#    'percent70Secs': 3.802,
#    'medianSecs': 3.4645,
#    'percent30Secs': 3.127,
#    'percent10Secs': 3.127,
#    'minSecs': 3.127}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82048184283138, 36.20245944033797],
#     [-86.82062178624496, 36.20264805972147]]},
#   'properties': {'fromStopId': 'BUEKIRNF',
#    'fromStopName': 'Buena Vista Pk & Kirk Ave Nb',
#    'toStopId': 'BUEYOUNN',
#    'toStopName': 'Buena Vista Pk & Youngs Ln Nb',
#    'pathLengthMeters': 24.445,
#    'averageTravelSeconds': 2.5496149999999997,
#    'averageTravelSpeed': 9.587722067841616,
#    'maxSecs': 3.989,
#    'percent90Secs': 3.664,
#    'percent80Secs': 3.011,
#    'percent70Secs': 2.87,
#    'medianSecs': 2.618,
#    'percent30Secs': 2.037,
#    'percent10Secs': 1.71,
#    'minSecs': 1.626}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8188590731843, 36.18646911340778],
#     [-86.81906814636861, 36.18658822681557]]},
#   'properties': {'fromStopId': 'CLA26ANN',
#    'fromStopName': 'Clarksville Pike & 26th Ave Nb',
#    'toStopId': 'CLAMETSN',
#    'toStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'pathLengthMeters': 22.967,
#    'averageTravelSeconds': 2.5485949999999997,
#    'averageTravelSpeed': 9.011631899144431,
#    'maxSecs': 6.474,
#    'percent90Secs': 3.939,
#    'percent80Secs': 3.052,
#    'percent70Secs': 2.522,
#    'medianSecs': 2.0755,
#    'percent30Secs': 1.939,
#    'percent10Secs': 1.599,
#    'minSecs': 1.309}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82430620848086, 36.18963315952903],
#     [-86.82453302472986, 36.18976320084512]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'HAMHYDWN',
#    'toStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'pathLengthMeters': 24.968,
#    'averageTravelSeconds': 1.47081,
#    'averageTravelSpeed': 16.97568006744583,
#    'maxSecs': 2.152,
#    'percent90Secs': 1.924,
#    'percent80Secs': 1.575,
#    'percent70Secs': 1.547,
#    'medianSecs': 1.459,
#    'percent30Secs': 1.353,
#    'percent10Secs': 1.155,
#    'minSecs': 1.135}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82124584689849, 36.210766272919855],
#     [-86.82151005480928, 36.210706844040196]]},
#   'properties': {'fromStopId': 'BUETAINF',
#    'fromStopName': 'Buena Vista Pk & Taigans Ct Nb',
#    'toStopId': 'STOTUCWN',
#    'toStopName': 'Stokers Ln & Tucker Rd Wb',
#    'pathLengthMeters': 24.608,
#    'averageTravelSeconds': 1.946538,
#    'averageTravelSpeed': 12.641931470127991,
#    'maxSecs': 2.31,
#    'percent90Secs': 2.26,
#    'percent80Secs': 2.167,
#    'percent70Secs': 2.088,
#    'medianSecs': 2,
#    'percent30Secs': 1.785,
#    'percent10Secs': 1.558,
#    'minSecs': 1.536}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82394576790801, 36.21075470516678],
#     [-86.82403356198112, 36.21095753974949]]},
#   'properties': {'fromStopId': 'STOTUCWN',
#    'fromStopName': 'Stokers Ln & Tucker Rd Wb',
#    'toStopId': 'TUCWHANN',
#    'toStopName': 'Tucker Rd & W Hamilton Rd Nb',
#    'pathLengthMeters': 23.89,
#    'averageTravelSeconds': 2.3530770000000003,
#    'averageTravelSpeed': 10.152663937474209,
#    'maxSecs': 3.232,
#    'percent90Secs': 3.114,
#    'percent80Secs': 2.712,
#    'percent70Secs': 2.598,
#    'medianSecs': 2.367,
#    'percent30Secs': 1.971,
#    'percent10Secs': 1.787,
#    'minSecs': 1.764}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.834855797033, 36.21876952736115],
#     [-86.83512206432273, 36.218739542306]]},
#   'properties': {'fromStopId': 'HPKL',
#    'fromStopName': 'Haynes Park Dr & Kings Ln Nb',
#    'toStopId': 'KINCLAW',
#    'toStopName': 'Kings Ln & Clarksville Pk Wb',
#    'pathLengthMeters': 24.118,
#    'averageTravelSeconds': 2.738538,
#    'averageTravelSpeed': 8.806888931247256,
#    'maxSecs': 3.854,
#    'percent90Secs': 3.642,
#    'percent80Secs': 3.306,
#    'percent70Secs': 3.04,
#    'medianSecs': 2.551,
#    'percent30Secs': 2.429,
#    'percent10Secs': 2.139,
#    'minSecs': 2.119}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82316548184225, 36.18896786232195],
#     [-86.82338831315805, 36.18909984702439]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'CLACLINN',
#    'toStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'pathLengthMeters': 24.805,
#    'averageTravelSeconds': 1.8408099999999998,
#    'averageTravelSpeed': 13.475046311134774,
#    'maxSecs': 3.664,
#    'percent90Secs': 3.061,
#    'percent80Secs': 2.113,
#    'percent70Secs': 2.03,
#    'medianSecs': 1.58,
#    'percent30Secs': 1.482,
#    'percent10Secs': 1.324,
#    'minSecs': 1.219}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81148005609643, 36.18013150952275],
#     [-86.81174508414465, 36.18014226428413]]},
#   'properties': {'fromStopId': 'BUCDBTWN',
#    'fromStopName': 'Buchanan St & Dr D B Todd Jr Blvd Wb',
#    'toStopId': 'BUC23AWN',
#    'toStopName': 'Buchanan St & 23rd Ave N Wb',
#    'pathLengthMeters': 23.817,
#    'averageTravelSeconds': 2.874314,
#    'averageTravelSpeed': 8.286151060740059,
#    'maxSecs': 7.154,
#    'percent90Secs': 4.032,
#    'percent80Secs': 3.553,
#    'percent70Secs': 3.23,
#    'medianSecs': 2.5735,
#    'percent30Secs': 2.259,
#    'percent10Secs': 1.864,
#    'minSecs': 1.699}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83943157417234, 36.21825969266924],
#     [-86.83970262636981, 36.21822966473008]]},
#   'properties': {'fromStopId': 'KINCLAW',
#    'fromStopName': 'Kings Ln & Clarksville Pk Wb',
#    'toStopId': 'KINTEMWF',
#    'toStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'pathLengthMeters': 24.544,
#    'averageTravelSeconds': 1.740231,
#    'averageTravelSpeed': 14.103874715483174,
#    'maxSecs': 2.117,
#    'percent90Secs': 2.113,
#    'percent80Secs': 1.927,
#    'percent70Secs': 1.872,
#    'medianSecs': 1.7,
#    'percent30Secs': 1.627,
#    'percent10Secs': 1.378,
#    'minSecs': 1.346}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.84461214999065, 36.213267124556076],
#     [-86.84460751167501, 36.21304680456288]]},
#   'properties': {'fromStopId': 'CRECRWSN',
#    'fromStopName': 'Creekwood & Creekway Ct Sb',
#    'toStopId': 'TIMFAISN',
#    'toStopName': 'Timothy Dr & Fairview Dr Sb',
#    'pathLengthMeters': 24.502,
#    'averageTravelSeconds': 2.7382310000000003,
#    'averageTravelSpeed': 8.948112850961076,
#    'maxSecs': 3.454,
#    'percent90Secs': 3.264,
#    'percent80Secs': 2.899,
#    'percent70Secs': 2.858,
#    'medianSecs': 2.708,
#    'percent30Secs': 2.604,
#    'percent10Secs': 2.367,
#    'minSecs': 2.326}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.78825, 36.16854],
#     [-86.78838035023047, 36.16873480913565]]},
#   'properties': {'fromStopId': '8AHARNN',
#    'fromStopName': '8th Ave N & Harrison St Nb',
#    'toStopId': '8A9ANM',
#    'toStopName': '8th Ave N & 9th Ave N Nb',
#    'pathLengthMeters': 24.62,
#    'averageTravelSeconds': 2.405948,
#    'averageTravelSpeed': 10.23297261619952,
#    'maxSecs': 12.843,
#    'percent90Secs': 2.71,
#    'percent80Secs': 2.446,
#    'percent70Secs': 2.303,
#    'medianSecs': 2.0615,
#    'percent30Secs': 1.906,
#    'percent10Secs': 1.636,
#    'minSecs': 1.47}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83819759693068, 36.190181395396024],
#     [-86.83806679590758, 36.18998519386137]]},
#   'properties': {'fromStopId': 'HYDMANSF',
#    'fromStopName': 'Hydes Ferry Rd & Manchester Ave Sb',
#    'toStopId': 'COUHYDWF',
#    'toStopName': 'County Hospital Rd & Hydes Ferry Rd',
#    'pathLengthMeters': 24.774,
#    'averageTravelSeconds': 2.5455,
#    'averageTravelSpeed': 9.732469063052445,
#    'maxSecs': 3.127,
#    'percent90Secs': 3.127,
#    'percent80Secs': 3.127,
#    'percent70Secs': 3.127,
#    'medianSecs': 2.5455,
#    'percent30Secs': 1.964,
#    'percent10Secs': 1.964,
#    'minSecs': 1.964}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8206073359036, 36.202287575293184],
#     [-86.82048184283138, 36.20245944033797]]},
#   'properties': {'fromStopId': 'BUEKIRNF',
#    'fromStopName': 'Buena Vista Pk & Kirk Ave Nb',
#    'toStopId': 'BUEYOUNN',
#    'toStopName': 'Buena Vista Pk & Youngs Ln Nb',
#    'pathLengthMeters': 24.445,
#    'averageTravelSeconds': 3.4863850000000003,
#    'averageTravelSpeed': 7.011560685351732,
#    'maxSecs': 7.736,
#    'percent90Secs': 7.656,
#    'percent80Secs': 4.585,
#    'percent70Secs': 3.44,
#    'medianSecs': 2.88,
#    'percent30Secs': 2.601,
#    'percent10Secs': 1.826,
#    'minSecs': 1.819}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81865, 36.18635],
#     [-86.8188590731843, 36.18646911340778]]},
#   'properties': {'fromStopId': 'CLA26ANN',
#    'fromStopName': 'Clarksville Pike & 26th Ave Nb',
#    'toStopId': 'CLAMETSN',
#    'toStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'pathLengthMeters': 22.967,
#    'averageTravelSeconds': 4.051524,
#    'averageTravelSpeed': 5.668731075022634,
#    'maxSecs': 14.765,
#    'percent90Secs': 11.534,
#    'percent80Secs': 6.313,
#    'percent70Secs': 3.116,
#    'medianSecs': 2.315,
#    'percent30Secs': 1.945,
#    'percent10Secs': 1.663,
#    'minSecs': 1.309}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82098163898772, 36.210825701799514],
#     [-86.82124584689849, 36.210766272919855]]},
#   'properties': {'fromStopId': 'BUETAINF',
#    'fromStopName': 'Buena Vista Pk & Taigans Ct Nb',
#    'toStopId': 'STOTUCWN',
#    'toStopName': 'Stokers Ln & Tucker Rd Wb',
#    'pathLengthMeters': 24.608,
#    'averageTravelSeconds': 1.950615,
#    'averageTravelSpeed': 12.615508442209252,
#    'maxSecs': 2.31,
#    'percent90Secs': 2.293,
#    'percent80Secs': 2.141,
#    'percent70Secs': 2.088,
#    'medianSecs': 2.018,
#    'percent30Secs': 1.786,
#    'percent10Secs': 1.558,
#    'minSecs': 1.536}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82407939223187, 36.18950311821294],
#     [-86.82430620848086, 36.18963315952903]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'HAMHYDWN',
#    'toStopName': 'S Hamilton Rd & N Hydes Ferry Rd Wb',
#    'pathLengthMeters': 24.968,
#    'averageTravelSeconds': 1.4742380000000002,
#    'averageTravelSpeed': 16.93620704391014,
#    'maxSecs': 2.152,
#    'percent90Secs': 1.924,
#    'percent80Secs': 1.575,
#    'percent70Secs': 1.547,
#    'medianSecs': 1.47,
#    'percent30Secs': 1.356,
#    'percent10Secs': 1.155,
#    'minSecs': 1.135}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83458952974327, 36.2187995124163],
#     [-86.834855797033, 36.21876952736115]]},
#   'properties': {'fromStopId': 'HPKL',
#    'fromStopName': 'Haynes Park Dr & Kings Ln Nb',
#    'toStopId': 'KINCLAW',
#    'toStopName': 'Kings Ln & Clarksville Pk Wb',
#    'pathLengthMeters': 24.118,
#    'averageTravelSeconds': 2.8330770000000003,
#    'averageTravelSpeed': 8.513005470730233,
#    'maxSecs': 4.531,
#    'percent90Secs': 4.26,
#    'percent80Secs': 3.43,
#    'percent70Secs': 3.04,
#    'medianSecs': 2.551,
#    'percent30Secs': 2.429,
#    'percent10Secs': 2.139,
#    'minSecs': 2.119}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.8238579738349, 36.21055187058408],
#     [-86.82394576790801, 36.21075470516678]]},
#   'properties': {'fromStopId': 'STOTUCWN',
#    'fromStopName': 'Stokers Ln & Tucker Rd Wb',
#    'toStopId': 'TUCWHANN',
#    'toStopName': 'Tucker Rd & W Hamilton Rd Nb',
#    'pathLengthMeters': 23.89,
#    'averageTravelSeconds': 3.261846,
#    'averageTravelSpeed': 7.324073546084028,
#    'maxSecs': 4.809,
#    'percent90Secs': 4.591,
#    'percent80Secs': 4.181,
#    'percent70Secs': 3.822,
#    'medianSecs': 3.26,
#    'percent30Secs': 2.502,
#    'percent10Secs': 2.144,
#    'minSecs': 2.041}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.81174508414465, 36.18014226428413],
#     [-86.81201011219287, 36.180153019045505]]},
#   'properties': {'fromStopId': 'BUCDBTWN',
#    'fromStopName': 'Buchanan St & Dr D B Todd Jr Blvd Wb',
#    'toStopId': 'BUC23AWN',
#    'toStopName': 'Buchanan St & 23rd Ave N Wb',
#    'pathLengthMeters': 23.817,
#    'averageTravelSeconds': 2.593929,
#    'averageTravelSpeed': 9.18182417483285,
#    'maxSecs': 13.794,
#    'percent90Secs': 3.31,
#    'percent80Secs': 3.011,
#    'percent70Secs': 2.652,
#    'medianSecs': 2.312,
#    'percent30Secs': 2.043,
#    'percent10Secs': 1.807,
#    'minSecs': 1.699}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.83916052197485, 36.2182897206084],
#     [-86.83943157417234, 36.21825969266924]]},
#   'properties': {'fromStopId': 'KINCLAW',
#    'fromStopName': 'Kings Ln & Clarksville Pk Wb',
#    'toStopId': 'KINTEMWF',
#    'toStopName': 'Kings Ln & Temple Church Park-N-Ride',
#    'pathLengthMeters': 24.544,
#    'averageTravelSeconds': 1.810231,
#    'averageTravelSpeed': 13.558490601475723,
#    'maxSecs': 2.438,
#    'percent90Secs': 2.425,
#    'percent80Secs': 2.057,
#    'percent70Secs': 1.882,
#    'medianSecs': 1.814,
#    'percent30Secs': 1.627,
#    'percent10Secs': 1.378,
#    'minSecs': 1.346}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-86.82338831315805, 36.18909984702439],
#     [-86.82361114447386, 36.18923183172683]]},
#   'properties': {'fromStopId': 'CLAMETSN',
#    'fromStopName': 'Clarksville Pike & Metrocenter Blvd',
#    'toStopId': 'CLACLINN',
#    'toStopName': 'Clarksville Pike & Cliff Dr Nb',
#    'pathLengthMeters': 24.805,
#    'averageTravelSeconds': 1.712333,
#    'averageTravelSpeed': 14.48608419039988,
#    'maxSecs': 2.945,
#    'percent90Secs': 2.398,
#    'percent80Secs': 2.057,
#    'percent70Secs': 1.765,
#    'medianSecs': 1.58,
#    'percent30Secs': 1.482,
#    'percent10Secs': 1.324,
#    'minSecs': 1.219}}]

# %%
# convert to GeoDataFrame the quick way
route22_gdf = gpd.GeoDataFrame.from_features(res)
route22_gdf
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.83379 36.21119, -86.83380 36.2...   HAYEVENN
# 1    LINESTRING (-86.84337 36.21173, -86.84310 36.2...   TIMFAISN
# 2    LINESTRING (-86.84064 36.20346, -86.84061 36.2...   CLAWHASN
# 3    LINESTRING (-86.83661 36.19440, -86.83684 36.1...   HAMHYDWN
# 4    LINESTRING (-86.82826 36.19319, -86.82810 36.1...    CLSFCLK
# ..                                                 ...        ...
# 912  LINESTRING (-86.83459 36.21880, -86.83486 36.2...       HPKL
# 913  LINESTRING (-86.82386 36.21055, -86.82395 36.2...   STOTUCWN
# 914  LINESTRING (-86.81175 36.18014, -86.81201 36.1...   BUCDBTWN
# 915  LINESTRING (-86.83916 36.21829, -86.83943 36.2...    KINCLAW
# 916  LINESTRING (-86.82339 36.18910, -86.82361 36.1...   CLAMETSN
#
#                              fromStopName  toStopId  \
# 0              Haynes Park Dr & Eve Cr Nb  HAYEFANN
# 1             Timothy Dr & Fairview Dr Sb  FAICLAEN
# 2      Clarksville Pike & W. Hamilton Ave  CLAABESN
# 3     S Hamilton Rd & N Hydes Ferry Rd Wb  JOHASHWF
# 4           Cliff Dr Past Clarksville Hwy  CLICLANM
# ..                                    ...       ...
# 912          Haynes Park Dr & Kings Ln Nb   KINCLAW
# 913             Stokers Ln & Tucker Rd Wb  TUCWHANN
# 914  Buchanan St & Dr D B Todd Jr Blvd Wb  BUC23AWN
# 915          Kings Ln & Clarksville Pk Wb  KINTEMWF
# 916   Clarksville Pike & Metrocenter Blvd  CLACLINN
#
#                                toStopName  pathLengthMeters  \
# 0         Haynes Park Dr & Fairview Dr Nb            23.516
# 1       Fairview Dr & Clarksville Pike Eb            24.391
# 2      Clarksville Pike & Abernathy Rd Sb            24.416
# 3        John Mallette Dr & Ashton Ave Wb            24.046
# 4          Cliff Dr & Clarksville Pike Nb            22.910
# ..                                    ...               ...
# 912          Kings Ln & Clarksville Pk Wb            24.118
# 913          Tucker Rd & W Hamilton Rd Nb            23.890
# 914           Buchanan St & 23rd Ave N Wb            23.817
# 915  Kings Ln & Temple Church Park-N-Ride            24.544
# 916        Clarksville Pike & Cliff Dr Nb            24.805
#
#      averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0                3.773538            6.231817    6.876          6.240
# 1                2.115154           11.531548    3.474          3.124
# 2                2.071750           11.785206    2.267          2.267
# 3                2.742000            8.769511    3.600          3.600
# 4                2.383750            9.610907    3.402          3.329
# ..                    ...                 ...      ...            ...
# 912              2.833077            8.513005    4.531          4.260
# 913              3.261846            7.324074    4.809          4.591
# 914              2.593929            9.181824   13.794          3.310
# 915              1.810231           13.558491    2.438          2.425
# 916              1.712333           14.486084    2.945          2.398
#
#      percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0            4.787          3.922      3.4090          3.362          2.340
# 1            2.552          2.228      1.8870          1.851          1.529
# 2            2.267          2.258      2.1085          1.886          1.803
# 3            3.600          3.600      2.7420          1.884          1.884
# 4            2.855          2.728      2.2780          2.120          1.575
# ..             ...            ...         ...            ...            ...
# 912          3.430          3.040      2.5510          2.429          2.139
# 913          4.181          3.822      3.2600          2.502          2.144
# 914          3.011          2.652      2.3120          2.043          1.807
# 915          2.057          1.882      1.8140          1.627          1.378
# 916          2.057          1.765      1.5800          1.482          1.324
#
#      minSecs
# 0      2.290
# 1      1.459
# 2      1.803
# 3      1.884
# 4      1.537
# ..       ...
# 912    2.119
# 913    2.041
# 914    1.699
# 915    1.346
# 916    1.219
#
# [917 rows x 16 columns]

# %%
URL= https://api.goswift.ly/run-times/{agencyKey}/route/{routeKey}/by-trip
# Out:
#   Input In [9]
#     URL= https://api.goswift.ly/run-times/{agencyKey}/route/{routeKey}/by-trip
#               ^
# SyntaxError: invalid syntax
