# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import requests
import geojson
import json 

# %matplotlib inline

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/22'

params = {
    'direction': '1',
    'startDate': '03-15-2022',
    'resolution': 'hiRes',
    'beginTime' : '06:00',
    'endTime' : '09:00'
}

params_geo  = {
    'direction': '1',
    'startDate': '04-01-2022',
    'endDate' : '04-30-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '06:00',
    'endTime' : '09:00',
    'resolution': 'hiRes'
}

headers = {'Authorization': Authorization,
         'Content-Type': 'application/json'}

# %%
# dig into json to get list of line-segment dicts
#response_line_segments = response_geo.json()['features']

# convert to GeoDataFrame the quick way
#route55_gdf = gpd.GeoDataFrame.from_features(response_line_segments)

# %%
response_geo = requests.get(URL, params = params_geo, headers=headers)

# %%
route22_features = response_geo.json()['features']

route22_gdf = gpd.GeoDataFrame.from_features(route22_features)
#route22_gdf['pathLengthMeters'].nunique()
route22_gdf #.sort_values(['fromStopId','averageTravelSeconds'],ascending=False).groupby('geometry').mean()
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.83661 36.19440, -86.83684 36.1...   HAMHYDWN
# 1    LINESTRING (-86.83752 36.18973, -86.83770 36.1...   COUDOAWN
# 2    LINESTRING (-86.81430 36.18268, -86.81428 36.1...   23ASEINF
# 3    LINESTRING (-86.78689 36.16764, -86.78708 36.1...    JAM8AWN
# 4    LINESTRING (-86.78293 36.16752, -86.78306 36.1...    MCC5_10
# ..                                                 ...        ...
# 523  LINESTRING (-86.84403 36.18345, -86.84422 36.1...   COUPANWN
# 524  LINESTRING (-86.81172 36.18014, -86.81199 36.1...   BUCDBTWN
# 525  LINESTRING (-86.81423 36.18328, -86.81421 36.1...   23ASEINF
# 526  LINESTRING (-86.82339 36.18910, -86.82361 36.1...   CLAMETSN
# 527  LINESTRING (-86.78650 36.16794, -86.78670 36.1...    JAM6AWN
#
#                              fromStopName  toStopId  \
# 0     S Hamilton Rd & N Hydes Ferry Rd Wb  JOHASHWF
# 1        County Hospital Rd & Doak Ave Wb  COUHYDWF
# ...
