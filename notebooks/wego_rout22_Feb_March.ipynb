# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import pandas as pd

# %%
import requests
import geojson
import json

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/56'

params_JantoFeb_mondayfriday = {
    'direction': '1', 
    'startDate': '02-25-2022',
    'endDate': '03-27-2022',
    'daysOfWeek': '1,5',
    'beginTime':'06:00',
    'endTime': '09:00',
    'resolution': 'hiRes',
     'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022'
} 
params_geo_JantoFeb_mondayfriday= {
    'direction': '1',
    'startDate': '02-25-2022',
    'endDate' : '03-27-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,5',
    'beginTime' : '06:00',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022'
}




params_JanFeb_TustoThru = {
    'direction': '1', 
    'startDate': '02-25-2022',
    'endDate': '03-27-2022',
    'daysOfWeek': '2,3,4',
    'beginTime':'06:00',
    'endTime': '09:00',
    'resolution': 'hiRes',
     'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022'
}

params_geo_JanFeb_TustoThru  = {
    'direction': '1',
    'startDate': '02-25-2022',
    'endDate' : '03-27-2022',
    'format'   : 'geojson',
    'daysOfWeek': '2,3,4',
    'beginTime' : '06:00',
    'endTime' : '09:00',
    'resolution': 'hiRes',
     'excludeDates': '03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022'
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

# %%
response_geo1 = requests.get(URL, params = params_geo_JantoFeb_mondayfriday, headers = headers)
result_geo1 =response_geo1.json()['features']
georout56_gdf=gpd.GeoDataFrame.from_features(result_geo1)
georout56_gdf['days'] = 'Monday&Friday'
georout56_gdf
# Out:
#                                               geometry fromStopId  \
# 0    LINESTRING (-86.70083 36.29509, -86.70098 36.2...   GXIMYASF
# 1    LINESTRING (-86.71756 36.25213, -86.71770 36.2...   GALEMMSN
# 2    LINESTRING (-86.73946 36.20187, -86.73957 36.2...   GXIEHILF
# 3    LINESTRING (-86.69581 36.30031, -86.69603 36.3...   GXIRIVEF
# 4    LINESTRING (-86.75448 36.17705, -86.75473 36.1...   GXIFIVEN
# ..                                                 ...        ...
# 726  LINESTRING (-86.72578 36.22314, -86.72580 36.2...    GXIINGF
# 727  LINESTRING (-86.72859 36.21751, -86.72870 36.2...   GALCURSN
# 728  LINESTRING (-86.74117 36.19872, -86.74128 36.1...   GALBURSN
# 729  LINESTRING (-86.72369 36.23978, -86.72373 36.2...   GALBERWF
# 730  LINESTRING (-86.73936 36.20207, -86.73946 36.2...   GXIEHILF
#
#                          fromStopName  toStopId  \
# 0               Myatt Station Inbound  GALALLSN
# 1     S Gallatin Pike & Emmitt Ave Sb  GXIDUESN
# 2           East Hill Station Inbound  GALBURSN
# 3                   Rivergate Station  GXIMYASF
# 4         Five Points Station Inbound  MAIMCFWN
# ..                                ...       ...
# 726         Inglewood Station Inbound  GALCURSN
# 727  Gallatin Pike & Curdwood Blvd Sb  GALGILSF
# 728        Gallatin Pk & Burchwood Av  GALCARSN
# 729   S Gallatin Pike & Berkley Dr Sb  GXIWALTF
# 730         East Hill Station Inbound  GALBURSN
#
#                            toStopName  pathLengthMeters  averageTravelSeconds  \
# 0     N Gallatin Pk & Alta Loma Rd Sb            23.437              1.758302
# 1            Due West Station Inbound            24.651              4.714000
# 2          Gallatin Pk & Burchwood Av            23.949              2.119632
# 3               Myatt Station Inbound            24.748              3.441403
# 4           Main St & Mcferrin Ave Wb            24.785              2.124944
# ..                                ...               ...                   ...
# 726  Gallatin Pike & Curdwood Blvd Sb            24.182              1.597220
# 727      Gallatin Pike & Gilock St Sb            24.257              1.601262
# 728      Gallatin Pk & Carolyn Ave Sb            23.951              1.798441
# 729            Walton Station Inbound            24.773              1.893874
# 730        Gallatin Pk & Burchwood Av            23.949              2.081214
#
#      averageTravelSpeed  maxSecs  percent90Secs  percent80Secs  percent70Secs  \
# 0             13.329337    4.095          2.231          1.935          1.836
# 1              5.229317   26.605         12.726          5.053          4.230
# 2             11.298659    3.996          3.318          2.528          2.196
# 3              7.191253    8.939          5.915          4.967          4.177
# 4             11.663837    6.514          2.617          2.310          2.162
# ..                  ...      ...            ...            ...            ...
# 726           15.140056    3.719          2.020          1.711          1.653
# 727           15.148676    2.583          1.925          1.802          1.707
# 728           13.317646    2.483          2.173          2.037          1.918
# 729           13.080596    6.776          2.724          2.191          1.958
# 730           11.507226    3.925          3.001          2.451          2.173
#
#      medianSecs  percent30Secs  percent10Secs  minSecs           days
# 0        1.6455          1.520          1.324    0.894  Monday&Friday
# 1        2.5170          1.937          1.588    1.354  Monday&Friday
# 2        1.8770          1.706          1.535    1.307  Monday&Friday
# 3        2.8710          2.263          1.574    0.841  Monday&Friday
# 4        1.9780          1.818          1.583    1.404  Monday&Friday
# ..          ...            ...            ...      ...            ...
# 726      1.5270          1.403          1.293    1.121  Monday&Friday
# 727      1.5595          1.455          1.322    1.134  Monday&Friday
# 728      1.7945          1.599          1.496    1.381  Monday&Friday
# 729      1.5770          1.402          1.283    1.162  Monday&Friday
# 730      1.9280          1.738          1.535    1.307  Monday&Friday
#
# [731 rows x 17 columns]

# %%
response_geo2 = requests.get(URL, params = params_JantoFeb_mondayfriday , headers = headers)
result2 =response_geo2.json()
rout56b_df=pd.DataFrame(result2['data']['segments'])
rout56b_df['days']='Monday&Friday'
rout56b_df
# Out:
#                                               pathLocs  maxSecs  \
# 0    [{'lat': 36.295087443684636, 'lon': -86.700831...    4.095
# 1    [{'lat': 36.25213235022493, 'lon': -86.7175640...   26.605
# 2    [{'lat': 36.20187189710303, 'lon': -86.7394645...    3.996
# 3    [{'lat': 36.30031185028378, 'lon': -86.6958057...    8.939
# 4    [{'lat': 36.17705382045483, 'lon': -86.7544769...    6.514
# ..                                                 ...      ...
# 726  [{'lat': 36.223143066739944, 'lon': -86.725778...    3.719
# 727  [{'lat': 36.21751118330021, 'lon': -86.7285890...    2.583
# 728  [{'lat': 36.19871719989628, 'lon': -86.7411702...    2.483
# 729  [{'lat': 36.239783325766865, 'lon': -86.723685...    6.776
# 730  [{'lat': 36.202068352980476, 'lon': -86.739355...    3.925
#
#      percent90Secs  percent80Secs  percent70Secs  medianSecs  percent30Secs  \
# 0            2.231          1.935          1.836      1.6455          1.520
# 1           12.726          5.053          4.230      2.5170          1.937
# 2            3.318          2.528          2.196      1.8770          1.706
# 3            5.915          4.967          4.177      2.8710          2.263
# 4            2.617          2.310          2.162      1.9780          1.818
# ..             ...            ...            ...         ...            ...
# 726          2.020          1.711          1.653      1.5270          1.403
# 727          1.925          1.802          1.707      1.5595          1.455
# 728          2.173          2.037          1.918      1.7945          1.599
# 729          2.724          2.191          1.958      1.5770          1.402
# 730          3.001          2.451          2.173      1.9280          1.738
#
#      percent20Secs  percent10Secs  minSecs  pathLengthMeters  \
# 0            1.407          1.324    0.894            23.437
# 1            1.757          1.588    1.354            24.651
# 2            1.617          1.535    1.307            23.949
# 3            1.820          1.574    0.841            24.748
# 4            1.683          1.583    1.404            24.785
# ..             ...            ...      ...               ...
# 726          1.367          1.293    1.121            24.182
# 727          1.375          1.322    1.134            24.257
# 728          1.554          1.496    1.381            23.951
# 729          1.333          1.283    1.162            24.773
# 730          1.634          1.535    1.307            23.949
#
#      averageTravelSeconds  averageTravelSpeed  \
# 0                1.758302           13.329337
# 1                4.714000            5.229317
# 2                2.119632           11.298659
# 3                3.441403            7.191253
# 4                2.124944           11.663837
# ..                    ...                 ...
# 726              1.597220           15.140056
# 727              1.601262           15.148676
# 728              1.798441           13.317646
# 729              1.893874           13.080596
# 730              2.081214           11.507226
#
#                                                 toStop  \
# 0    {'configRev': 53, 'stopPathId': 'GXIMYASF_to_G...
# 1    {'configRev': 53, 'stopPathId': 'GALEMMSN_to_G...
# 2    {'configRev': 53, 'stopPathId': 'GXIEHILF_to_G...
# 3    {'configRev': 53, 'stopPathId': 'GXIRIVEF_to_G...
# 4    {'configRev': 53, 'stopPathId': 'GXIFIVEN_to_M...
# ..                                                 ...
# 726  {'configRev': 53, 'stopPathId': 'GXIINGF_to_GA...
# 727  {'configRev': 53, 'stopPathId': 'GALCURSN_to_G...
# 728  {'configRev': 53, 'stopPathId': 'GALBURSN_to_G...
# 729  {'configRev': 53, 'stopPathId': 'GALBERWF_to_G...
# 730  {'configRev': 53, 'stopPathId': 'GXIEHILF_to_G...
#
#                                               fromStop  countForSegment  \
# 0    {'configRev': 53, 'stopPathId': 'GXIRIVEF_to_G...              116
# 1    {'configRev': 53, 'stopPathId': 'GXIMADLB_to_G...              119
# 2    {'configRev': 53, 'stopPathId': 'GALMAYSN_to_G...              117
# 3    {'configRev': 53, 'stopPathId': 'to_GXIRIVEF',...               67
# 4    {'configRev': 53, 'stopPathId': 'GXIEASTN_to_G...              125
# ..                                                 ...              ...
# 726  {'configRev': 53, 'stopPathId': 'GALBROSF_to_G...              123
# 727  {'configRev': 53, 'stopPathId': 'GXIINGF_to_GA...              122
# 728  {'configRev': 53, 'stopPathId': 'GXIEHILF_to_G...              118
# 729  {'configRev': 53, 'stopPathId': 'GXIDUESN_to_G...              127
# 730  {'configRev': 53, 'stopPathId': 'GALMAYSN_to_G...              117
#
#               days
# 0    Monday&Friday
# 1    Monday&Friday
# 2    Monday&Friday
# 3    Monday&Friday
# 4    Monday&Friday
# ..             ...
# 726  Monday&Friday
# 727  Monday&Friday
# 728  Monday&Friday
# 729  Monday&Friday
# 730  Monday&Friday
#
# [731 rows x 17 columns]

# %%
rout56_inbound_MandF_concat = pd.concat([georout56_gdf,rout22b_df[['countForSegment','percent20Secs']]], axis = 1)
rout56_inbound_MandF_concat
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.83661 36.19440, -86.83684 36.1...   HAMHYDWN
# 1  LINESTRING (-86.83752 36.18973, -86.83770 36.1...   COUDOAWN
# 2  LINESTRING (-86.81430 36.18268, -86.81428 36.1...   23ASEINF
#
#                           fromStopName  toStopId  \
# 0  S Hamilton Rd & N Hydes Ferry Rd Wb  JOHASHWF
# 1     County Hospital Rd & Doak Ave Wb  COUHYDWF
# 2          23rd Ave N & Seifried St Nb  23ACLANN
#
#                             toStopName  pathLengthMeters  \
# 0     John Mallette Dr & Ashton Ave Wb            24.046
# 1  County Hospital Rd & Hydes Ferry Rd            24.241
# 2     23rd Ave N & Clarksville Pike Nb            22.407
#
#    averageTravelSeconds  averageTravelSpeed  maxSecs  percent90Secs  \
# 0             13.270667            1.811966   23.794         21.994
# 1              1.736833           13.957013    4.951          1.933
# 2              2.315978            9.674962    7.796          2.923
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent10Secs  \
# 0         19.667         16.882     14.6090          7.537          4.910
# 1          1.752          1.700      1.5445          1.447          1.294
# 2          2.511          2.349      2.1360          1.874          1.657
#
#    minSecs  countForSegment  percent20Secs
# 0    4.261               15          6.079
# 1    1.103               30          1.331
# 2    1.080              134          1.757

# %%
response_geo11 = requests.get(URL, params = params_geo_JanFeb_TustoThru, headers = headers)
result_geo11 =response_geo11.json()['features']
georout56_Tu_thu_gdf=gpd.GeoDataFrame.from_features(result_geo11)
georout56_Tu_thu_gdf['days'] = 'Tuesday to Thursday'
georout56_Tu_thu_gdf.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70083 36.29509, -86.70098 36.2...   GXIMYASF
# 1  LINESTRING (-86.71756 36.25213, -86.71770 36.2...   GALEMMSN
#
#                       fromStopName  toStopId                       toStopName  \
# 0            Myatt Station Inbound  GALALLSN  N Gallatin Pk & Alta Loma Rd Sb
# 1  S Gallatin Pike & Emmitt Ave Sb  GXIDUESN         Due West Station Inbound
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.437              1.885870           12.427686    4.936
# 1            24.651              4.598283            5.360914   34.564
#
#    percent90Secs  percent80Secs  percent70Secs  medianSecs  percent30Secs  \
# 0          2.704          2.180          1.904       1.674          1.522
# 1         11.501          5.902          3.976       2.427          1.911
#
#    percent10Secs  minSecs                 days
# 0          1.365    1.191  Tuesday to Thursday
# 1          1.602    1.329  Tuesday to Thursday

# %%
response_geo56 = requests.get(URL, params = params_JanFeb_TustoThru , headers = headers)
result56 =response_geo22.json()
rout56b_tus_thu_df=pd.DataFrame(result56['data']['segments'])
rout56b_tus_thu_df['days']='Tuesday to Thursday'
rout56b_tus_thu_df.head(2)
# Out:
#                                             pathLocs  maxSecs  percent90Secs  \
# 0  [{'lat': 36.295087443684636, 'lon': -86.700831...    4.936          2.704
# 1  [{'lat': 36.25213235022493, 'lon': -86.7175640...   34.564         11.501
#
#    percent80Secs  percent70Secs  medianSecs  percent30Secs  percent20Secs  \
# 0          2.180          1.904       1.674          1.522          1.450
# 1          5.902          3.976       2.427          1.911          1.737
#
#    percent10Secs  minSecs  pathLengthMeters  averageTravelSeconds  \
# 0          1.365    1.191            23.437              1.885870
# 1          1.602    1.329            24.651              4.598283
#
#    averageTravelSpeed                                             toStop  \
# 0           12.427686  {'configRev': 53, 'stopPathId': 'GXIMYASF_to_G...
# 1            5.360914  {'configRev': 53, 'stopPathId': 'GALEMMSN_to_G...
#
#                                             fromStop  countForSegment  \
# 0  {'configRev': 53, 'stopPathId': 'GXIRIVEF_to_G...              207
# 1  {'configRev': 53, 'stopPathId': 'GXIMADLB_to_G...              212
#
#                   days
# 0  Tuesday to Thursday
# 1  Tuesday to Thursday

# %%
rout56_inbound_TustoThu_concat = pd.concat([georout56_Tu_thu_gdf,rout56b_tus_thu_df[['countForSegment','percent20Secs']]], axis = 1)
rout56_inbound_TustoThu_concat.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70083 36.29509, -86.70098 36.2...   GXIMYASF
# 1  LINESTRING (-86.71756 36.25213, -86.71770 36.2...   GALEMMSN
#
#                       fromStopName  toStopId                       toStopName  \
# 0            Myatt Station Inbound  GALALLSN  N Gallatin Pk & Alta Loma Rd Sb
# 1  S Gallatin Pike & Emmitt Ave Sb  GXIDUESN         Due West Station Inbound
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.437              1.885870           12.427686    4.936
# 1            24.651              4.598283            5.360914   34.564
#
#    percent90Secs  percent80Secs  percent70Secs  medianSecs  percent30Secs  \
# 0          2.704          2.180          1.904       1.674          1.522
# 1         11.501          5.902          3.976       2.427          1.911
#
#    percent10Secs  minSecs                 days  countForSegment  percent20Secs
# 0          1.365    1.191  Tuesday to Thursday              207          1.450
# 1          1.602    1.329  Tuesday to Thursday              212          1.737
