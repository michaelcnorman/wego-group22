# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import requests
import geojson
import json
import numpy as np

# %matplotlib inline

# %%
with open('../data/WeGo.json') as fi:
    credentials = json.load(fi)

# %%
Authorization = credentials['Authorization']

# %%
Authorization
# Out:
# '5f2680b713bddbda2b2a03bf89fa4751'

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/56'
#AM PEAK IN BOUND----------------------------
params_April_AMPeak = {
    'direction': '1',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '06:00',
    'endTime' : '09:00',
}
params_geo_April_AMPeak  = {
    'direction': '1',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '06:00',
    'endTime' : '09:00',
    'resolution': 'hiRes',
}
params_May_AMPeak = {
    'direction': '1',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '06:00',
    'endTime' : '09:00',
    'excludeDates' : '05-30-2022',
}
params_geo_May_AMPeak  = {
    'direction': '1',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '06:00',
    'endTime' : '09:00',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',
}
#OFFPEAK INBOUND------------------------
params_April_offpeak_in = {
    'direction': ('1'),
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '09:00',
    'endTime' : '14:30',
}
params_geo_April_offpeak_in = {
    'direction': ('1'),
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'resolution': 'hiRes',
}
#----------------------------------
params_April_offpeak_out = {
    'direction': ('0'),
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '09:00',
    'endTime' : '14:30',
}
params_geo_April_offpeak_out = {
    'direction': ('0'),
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'resolution': 'hiRes',
}
#--------------------------
params_May_offpeak_in = {
    'direction': ('1'),
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'excludeDates' : '05-30-2022',
}
params_geo_May_offpeak_in = {
    'direction': ('1'),
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',   
}
#----------------------------
params_May_offpeak_out = {
    'direction': ('0'),
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'excludeDates' : '05-30-2022',
}
params_geo_May_offpeak_out = {
    'direction': ('0'),
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '09:00',
    'endTime' : '14:30',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',
}
#PM PEAK OUTBOUND--------------------
params_April_PMPeak = {
    'direction': '0',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '14:30',
    'endTime' : '18:00',
}
params_geo_April_PMPeak  = {
    'direction': '0',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '14:30',
    'endTime' : '18:00',
    'resolution': 'hiRes',
}
params_May_PMPeak = {
    'direction': '0',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '14:30',
    'endTime' : '18:00',
    'excludeDates' : '05-30-2022',
}
params_geo_May_APMPeak  = {
    'direction': '0',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '14:30',
    'endTime' : '18:00',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',    
}
# EVENING INBOUND------------------------
params_April_Evening_In = {
    'direction': '1',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '18:00',
    'endTime' : '23:59',
}
params_geo_April_Evening_In  = {
    'direction': '1',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '18:00',
    'endTime' : '23:59',
    'resolution': 'hiRes',
}
params_May_Evening_In = {
    'direction': '1',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '18:00',
    'endTime' : '23:59',
    'excludeDates' : '05-30-2022',
}
params_geo_May_Evening_In  = {
    'direction': '1',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '18:00',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',
}

#EVENING OUTBOUND
params_April_Evening_out = {
    'direction': '0',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '18:00',
    'endTime' : '23:59',
}
params_geo_April_Evening_out  = {
    'direction': '0',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '18:00',
    'endTime' : '23:59',
    'resolution': 'hiRes',
}
params_May_Evening_out = {
    'direction': '0',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '18:00',
    'endTime' : '23:59',
    'excludeDates' : '05-30-2022',
}
params_geo_May_Evening_out  = {
    'direction': '0',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '18:00',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',
}
# EARLY AM INBOUND-------------------
params_April_EarlyAM_In = {
    'direction': '1',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '00:00',
    'endTime' : '06:00',
}
params_geo_April_EarlyAM_In  = {
    'direction': '1',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '00:00',
    'endTime' : '06:00',
    'resolution': 'hiRes',
}
params_May_EarlyAM_In = {
    'direction': '1',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '00:00',
    'endTime' : '06:00',
    'excludeDates' : '05-30-2022',
}
params_geo_May_EarlyAM_In  = {
    'direction': '1',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '00:00',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',
}

#EARLY AM OUTBOUND
params_April_EarlyAM_out = {
    'direction': '0',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '00:00',
    'endTime' : '06:00',
}
params_geo_April_EarlyAM_out  = {
    'direction': '0',
    'startDate': '03-25-2022',
    'endDate': '04-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '00:00',
    'endTime' : '06:00',
    'resolution': 'hiRes',
}
params_May_EarlyAM_out = {
    'direction': '0',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'daysOfWeek': '1,2,3,4,5',
    'resolution': 'hiRes',
    'beginTime' : '00:00',
    'endTime' : '06:00',
    'excludeDates' : '05-30-2022',
}
params_geo_May_EarlyAM_out  = {
    'direction': '0',
    'startDate': '04-25-2022',
    'endDate': '05-24-2022',
    'format'   : 'geojson',
    'daysOfWeek': '1,2,3,4,5',
    'beginTime' : '00:00',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates' : '05-30-2022',
}
headers = {'Authorization': Authorization,
         'Content-Type': 'application/json'}

# %%
def concat_frames_columns(geo_response, response, date_range, time_range='6am-9am', days='m-f', in_or_out='inbound'):
    """This function pulls in two API requests, puts one in a geodataframe the other in a dataframe and concats desired columns"""
    geo_df = gpd.GeoDataFrame.from_features(geo_response.json()['features'])
    res_df = pd.DataFrame(response.json()['data']['segments'])
    full_df = pd.concat([geo_df, res_df[['countForSegment', 'percent20Secs']]], axis = 1)
    full_df['dates'] = date_range
    full_df['time'] = time_range
    full_df['days_of_week'] = days
    full_df['direction']= in_or_out
    full_df['max_seg_count'] = full_df['countForSegment'].max()
    return full_df

# %% [markdown]
# trial = concat_frames_columns(requests.get(URL, params = params, headers = headers),
#                               requests.get(URL, params = params1, headers = headers), '01/25/22-02/24/22')

# %% [markdown]
# # AM PEAK INBOUND

# %%
r56_ampeak_apr=concat_frames_columns(requests.get(URL, params = params_geo_April_AMPeak, headers = headers), 
                              requests.get(URL, params = params_April_AMPeak, headers = headers), '03/25/22-04/24/22',
                              '06:00-09:00','m_f','Inbound')

# %%
seg_filter_r56_ampeak_apr=r56_ampeak_apr[r56_ampeak_apr['countForSegment'] > r56_ampeak_apr['countForSegment'].max()/2]

# %%
clean_geo_r56_ampeak_apr=seg_filter_r56_ampeak_apr[seg_filter_r56_ampeak_apr['percent20Secs']>=np.percentile(seg_filter_r56_ampeak_apr['percent20Secs'], 80)]

# %%
clean_geo_r56_ampeak_apr.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 365  LINESTRING (-86.78159 36.16633, -86.78182 36.1...   JAMGAYWF
# 319  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 379  LINESTRING (-86.78135 36.16642, -86.78159 36.1...   JAMGAYWF
# 456  LINESTRING (-86.78111 36.16652, -86.78135 36.1...   JAMGAYWF
# 697  LINESTRING (-86.78103 36.16682, -86.78091 36.1...   JAMGAYWF
#
#                          fromStopName  toStopId  \
# 365  James Robertson Pkwy & Gay St Wb   MCC4_18
# 319           Madison Station Inbound  GALEMMSN
# 379  James Robertson Pkwy & Gay St Wb   MCC4_18
# 456  James Robertson Pkwy & Gay St Wb   MCC4_18
# 697  James Robertson Pkwy & Gay St Wb   MCC4_18
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 365         Central 4th Ave - Bay 18            23.878             73.004303
# 319  S Gallatin Pike & Emmitt Ave Sb            23.806             95.697744
# 379         Central 4th Ave - Bay 18            23.878             20.117310
# 456         Central 4th Ave - Bay 18            23.878             12.066226
# 697         Central 4th Ave - Bay 18            23.878              8.752030
#
#      averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 365            0.327077  547.338        113.843  ...         43.544
# 319            0.248762  400.669        217.129  ...         32.958
# 379            1.186938  275.631         26.980  ...         15.876
# 456            1.978912  275.631         16.967  ...          8.215
# 697            2.728281  275.631         10.709  ...          5.506
#
#      percent10Secs  minSecs  countForSegment  percent20Secs  \
# 365         24.926    2.401              211         34.658
# 319          6.877    1.581              363         20.486
# 379          6.777    2.401              216         14.494
# 456          5.121    2.401              221          6.730
# 697          4.257    2.401              232          4.974
#
#                  dates         time  days_of_week direction max_seg_count
# 365  03/25/22-04/24/22  06:00-09:00           m_f   Inbound           389
# 319  03/25/22-04/24/22  06:00-09:00           m_f   Inbound           389
# 379  03/25/22-04/24/22  06:00-09:00           m_f   Inbound           389
# 456  03/25/22-04/24/22  06:00-09:00           m_f   Inbound           389
# 697  03/25/22-04/24/22  06:00-09:00           m_f   Inbound           389
#
# [5 rows x 23 columns]

# %% [markdown]
# # AM PEAK MAY INBOUND

# %%
r56_ampeak_may=concat_frames_columns(requests.get(URL, params = params_geo_May_AMPeak, headers = headers), 
                              requests.get(URL, params = params_May_AMPeak, headers = headers), '04/25/22-05/24/22',
                              '06:00-09:00','m_f','Inbound')

# %%
seg_filter_r56_ampeak_may=r56_ampeak_may[r56_ampeak_may['countForSegment'] > r56_ampeak_may['countForSegment'].max()/2]

# %%
clean_geo_r56_ampeak_may=seg_filter_r56_ampeak_may[seg_filter_r56_ampeak_may['percent20Secs']>=np.percentile(seg_filter_r56_ampeak_may['percent20Secs'], 80)]

# %%
clean_geo_r56_ampeak_may.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 188  LINESTRING (-86.78159 36.16633, -86.78182 36.1...   JAMGAYWF
# 425  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 198  LINESTRING (-86.78135 36.16642, -86.78159 36.1...   JAMGAYWF
# 242  LINESTRING (-86.78111 36.16652, -86.78135 36.1...   JAMGAYWF
# 398  LINESTRING (-86.78103 36.16682, -86.78091 36.1...   JAMGAYWF
#
#                          fromStopName  toStopId  \
# 188  James Robertson Pkwy & Gay St Wb   MCC4_18
# 425           Madison Station Inbound  GALEMMSN
# 198  James Robertson Pkwy & Gay St Wb   MCC4_18
# 242  James Robertson Pkwy & Gay St Wb   MCC4_18
# 398  James Robertson Pkwy & Gay St Wb   MCC4_18
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 188         Central 4th Ave - Bay 18            23.878             95.996251
# 425  S Gallatin Pike & Emmitt Ave Sb            23.895            103.527148
# 198         Central 4th Ave - Bay 18            23.878             22.716456
# 242         Central 4th Ave - Bay 18            23.878             11.819828
# 398         Central 4th Ave - Bay 18            23.878              7.933615
#
#      averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 188            0.248739  884.494        193.426  ...         47.039
# 425            0.230809  522.791        256.225  ...         32.889
# 198            1.051132  558.935         31.861  ...         15.739
# 242            2.020165  118.060         17.652  ...          8.682
# 398            3.009725  118.060         12.896  ...          5.355
#
#      percent10Secs  minSecs  countForSegment  percent20Secs  \
# 188         15.898    2.076              327         35.279
# 425          7.700    1.300              372         17.498
# 198          5.877    2.076              338         13.231
# 242          3.955    2.076              344          7.041
# 398          3.785    2.006              358          4.840
#
#                  dates         time  days_of_week direction max_seg_count
# 188  04/25/22-05/24/22  06:00-09:00           m_f   Inbound           411
# 425  04/25/22-05/24/22  06:00-09:00           m_f   Inbound           411
# 198  04/25/22-05/24/22  06:00-09:00           m_f   Inbound           411
# 242  04/25/22-05/24/22  06:00-09:00           m_f   Inbound           411
# 398  04/25/22-05/24/22  06:00-09:00           m_f   Inbound           411
#
# [5 rows x 23 columns]

# %% [markdown]
# # APRIL OFF PEAK INBOUND

# %%
r56_offpeak_apr_in=concat_frames_columns(requests.get(URL, params = params_geo_April_offpeak_in, headers = headers), 
                              requests.get(URL, params = params_April_offpeak_in, headers = headers), '03/25/22-04/24/22',
                              '09:00-14:30','m_f','Inbound')

# %%
seg_filter_r56_offpeak_apr_in=r56_offpeak_apr_in[r56_offpeak_apr_in['countForSegment'] > r56_offpeak_apr_in['countForSegment'].max()/2]

# %%
clean_geo_r56_offpeak_apr_in=seg_filter_r56_offpeak_apr_in[seg_filter_r56_offpeak_apr_in['percent20Secs']>=np.percentile(seg_filter_r56_offpeak_apr_in['percent20Secs'], 80)]

# %%
clean_geo_r56_offpeak_apr_in.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 365  LINESTRING (-86.78159 36.16633, -86.78182 36.1...   JAMGAYWF
# 319  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 379  LINESTRING (-86.78135 36.16642, -86.78159 36.1...   JAMGAYWF
# 456  LINESTRING (-86.78111 36.16652, -86.78135 36.1...   JAMGAYWF
# 431  LINESTRING (-86.78091 36.16663, -86.78111 36.1...   JAMGAYWF
#
#                          fromStopName  toStopId  \
# 365  James Robertson Pkwy & Gay St Wb   MCC4_18
# 319           Madison Station Inbound  GALEMMSN
# 379  James Robertson Pkwy & Gay St Wb   MCC4_18
# 456  James Robertson Pkwy & Gay St Wb   MCC4_18
# 431  James Robertson Pkwy & Gay St Wb   MCC4_18
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 365         Central 4th Ave - Bay 18            23.878            114.339672
# 319  S Gallatin Pike & Emmitt Ave Sb            23.806            102.491125
# 379         Central 4th Ave - Bay 18            23.878             28.828222
# 456         Central 4th Ave - Bay 18            23.878             13.487496
# 431         Central 4th Ave - Bay 18            23.878              7.892498
#
#      averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 365            0.208834  960.699        212.433  ...         63.593
# 319            0.232274  463.799        228.592  ...         34.152
# 379            0.828286  383.453         39.343  ...         17.011
# 456            1.770381  185.238         18.505  ...          9.721
# 431            3.025405  166.397         10.017  ...          5.896
#
#      percent10Secs  minSecs  countForSegment  percent20Secs  \
# 365         30.762    2.716              384         44.418
# 319          6.849    1.650              689         17.869
# 379         10.843    2.595              396         14.884
# 456          5.472    2.595              399          7.487
# 431          4.483    2.595              414          5.358
#
#                  dates         time  days_of_week direction max_seg_count
# 365  03/25/22-04/24/22  09:00-14:30           m_f   Inbound           702
# 319  03/25/22-04/24/22  09:00-14:30           m_f   Inbound           702
# 379  03/25/22-04/24/22  09:00-14:30           m_f   Inbound           702
# 456  03/25/22-04/24/22  09:00-14:30           m_f   Inbound           702
# 431  03/25/22-04/24/22  09:00-14:30           m_f   Inbound           702
#
# [5 rows x 23 columns]

# %% [markdown]
# # APRIL OFFPEAK OUTBOUND

# %%
r56_offpeak_apr_out=concat_frames_columns(requests.get(URL, params = params_geo_April_offpeak_out, headers = headers), 
                              requests.get(URL, params = params_April_offpeak_out, headers = headers), '03/25/22-04/24/22',
                              '14:30-18:00','m_f','Outbound')

# %%
seg_filter_r56_offpeak_apr_out=r56_offpeak_apr_out[r56_offpeak_apr_out['countForSegment'] > r56_offpeak_apr_out['countForSegment'].max()/2]

# %%
clean_geo_r56_offpeak_apr_out=seg_filter_r56_offpeak_apr_out[seg_filter_r56_offpeak_apr_out['percent20Secs']>=np.percentile(seg_filter_r56_offpeak_apr_out['percent20Secs'], 80)]

# %%
clean_geo_r56_offpeak_apr_out.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 420  LINESTRING (-86.69531 36.30058, -86.69554 36.3...   GALCONSF
# 385  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
# 289  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
# 345  LINESTRING (-86.68661 36.30757, -86.68667 36.3...    GALWMRT
# 375  LINESTRING (-86.68616 36.30781, -86.68639 36.3...    GALWMRT
#
#                        fromStopName  toStopId                      toStopName  \
# 420  Gallatin Pk & Conference Dr Sb  GXIRIVEF               Rivergate Station
# 385           Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 289        Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 345           Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 375           Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed   maxSecs  \
# 420            24.642            417.654520            0.059001  1230.381
# 385            24.481             76.416139            0.320364  1074.067
# 289            24.574             60.881786            0.403635   572.755
# 345            24.481             13.955668            1.754198   483.408
# 375            24.481             12.093066            2.024383   487.639
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 420        740.175  ...        274.173         11.213    2.350
# 385        153.287  ...         24.188         10.020    0.396
# 289        163.127  ...         14.729          3.879    1.550
# 345         21.615  ...          7.068          5.901    0.396
# 375         12.386  ...          6.337          5.362    0.396
#
#      countForSegment  percent20Secs              dates         time  \
# 420              523        129.651  03/25/22-04/24/22  14:30-18:00
# 385              676         17.402  03/25/22-04/24/22  14:30-18:00
# 289              676          8.529  03/25/22-04/24/22  14:30-18:00
# 345              678          6.410  03/25/22-04/24/22  14:30-18:00
# 375              678          5.877  03/25/22-04/24/22  14:30-18:00
#
#      days_of_week direction max_seg_count
# 420           m_f  Outbound           701
# 385           m_f  Outbound           701
# 289           m_f  Outbound           701
# 345           m_f  Outbound           701
# 375           m_f  Outbound           701
#
# [5 rows x 23 columns]

# %% [markdown]
# # MAY OFFPEAK INBOUND

# %%
r56_offpeak_may_in=concat_frames_columns(requests.get(URL, params = params_geo_May_offpeak_in, headers = headers), 
                              requests.get(URL, params = params_May_offpeak_in, headers = headers), '04/25/22-05/24/22',
                              '14:30-18:00','m_f','Inbound')
r56_offpeak_may_in.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.73946 36.20187, -86.73957 36.2...   GXIEHILF
# 1  LINESTRING (-86.77859 36.16773, -86.77882 36.1...   JAMGAYWF
#
#                        fromStopName  toStopId                  toStopName  \
# 0         East Hill Station Inbound  GALBURSN  Gallatin Pk & Burchwood Av
# 1  James Robertson Pkwy & Gay St Wb   MCC4_18    Central 4th Ave - Bay 18
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.949              2.242274           10.680675   25.950
# 1            23.878              3.029295            7.882362   34.424
#
#    percent90Secs  ...  percent30Secs  percent10Secs  minSecs  countForSegment  \
# 0          3.160  ...          1.801          1.596    1.279              708
# 1          4.329  ...          2.198          1.758    0.742              698
#
#    percent20Secs              dates         time  days_of_week direction  \
# 0          1.702  04/25/22-05/24/22  14:30-18:00           m_f   Inbound
# 1          2.025  04/25/22-05/24/22  14:30-18:00           m_f   Inbound
#
#   max_seg_count
# 0           722
# 1           722
#
# [2 rows x 23 columns]

# %%
seg_filter_r56_offpeak_may_in=r56_offpeak_may_in[r56_offpeak_may_in['countForSegment'] > r56_offpeak_may_in['countForSegment'].max()/2]
seg_filter_r56_offpeak_may_in.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.73946 36.20187, -86.73957 36.2...   GXIEHILF
# 1  LINESTRING (-86.77859 36.16773, -86.77882 36.1...   JAMGAYWF
#
#                        fromStopName  toStopId                  toStopName  \
# 0         East Hill Station Inbound  GALBURSN  Gallatin Pk & Burchwood Av
# 1  James Robertson Pkwy & Gay St Wb   MCC4_18    Central 4th Ave - Bay 18
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.949              2.242274           10.680675   25.950
# 1            23.878              3.029295            7.882362   34.424
#
#    percent90Secs  ...  percent30Secs  percent10Secs  minSecs  countForSegment  \
# 0          3.160  ...          1.801          1.596    1.279              708
# 1          4.329  ...          2.198          1.758    0.742              698
#
#    percent20Secs              dates         time  days_of_week direction  \
# 0          1.702  04/25/22-05/24/22  14:30-18:00           m_f   Inbound
# 1          2.025  04/25/22-05/24/22  14:30-18:00           m_f   Inbound
#
#   max_seg_count
# 0           722
# 1           722
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_offpeak_may_in=seg_filter_r56_offpeak_may_in[seg_filter_r56_offpeak_may_in['percent20Secs']>=np.percentile(seg_filter_r56_offpeak_may_in['percent20Secs'], 80)]
clean_geo_r56_offpeak_may_in.head(2)
# Out:
#                                              geometry fromStopId  \
# 1   LINESTRING (-86.77859 36.16773, -86.77882 36.1...   JAMGAYWF
# 12  LINESTRING (-86.74382 36.19376, -86.74392 36.1...   GALCARSN
#
#                         fromStopName  toStopId                toStopName  \
# 1   James Robertson Pkwy & Gay St Wb   MCC4_18  Central 4th Ave - Bay 18
# 12      Gallatin Pk & Carolyn Ave Sb  GXIDOUGN   Douglas Station Inbound
#
#     pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 1             23.878              3.029295            7.882362   34.424
# 12            23.971              3.884693            6.170629   52.662
#
#     percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 1           4.329  ...          2.198          1.758    0.742
# 12          6.201  ...          2.014          1.667    0.987
#
#     countForSegment  percent20Secs              dates         time  \
# 1               698          2.025  04/25/22-05/24/22  14:30-18:00
# 12              706          1.856  04/25/22-05/24/22  14:30-18:00
#
#     days_of_week direction max_seg_count
# 1            m_f   Inbound           722
# 12           m_f   Inbound           722
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_offpeak_may_in.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 188  LINESTRING (-86.78159 36.16633, -86.78182 36.1...   JAMGAYWF
# 425  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 198  LINESTRING (-86.78135 36.16642, -86.78159 36.1...   JAMGAYWF
# 242  LINESTRING (-86.78111 36.16652, -86.78135 36.1...   JAMGAYWF
# 398  LINESTRING (-86.78103 36.16682, -86.78091 36.1...   JAMGAYWF
#
#                          fromStopName  toStopId  \
# 188  James Robertson Pkwy & Gay St Wb   MCC4_18
# 425           Madison Station Inbound  GALEMMSN
# 198  James Robertson Pkwy & Gay St Wb   MCC4_18
# 242  James Robertson Pkwy & Gay St Wb   MCC4_18
# 398  James Robertson Pkwy & Gay St Wb   MCC4_18
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 188         Central 4th Ave - Bay 18            23.878            109.074140
# 425  S Gallatin Pike & Emmitt Ave Sb            23.895            111.024653
# 198         Central 4th Ave - Bay 18            23.878             28.519668
# 242         Central 4th Ave - Bay 18            23.878             14.559207
# 398         Central 4th Ave - Bay 18            23.878              9.907272
#
#      averageTravelSpeed   maxSecs  percent90Secs  ...  percent30Secs  \
# 188            0.218915  1049.088        225.395  ...         49.849
# 425            0.215222   425.957        246.072  ...         42.453
# 198            0.837247   345.119         49.305  ...         16.476
# 242            1.640062   265.708         20.124  ...          9.145
# 398            2.410149   383.217         16.654  ...          5.833
#
#      percent10Secs  minSecs  countForSegment  percent20Secs  \
# 188         24.314    2.233              537         36.607
# 425         10.196    1.736              677         26.016
# 198          8.234    2.233              579         14.319
# 242          5.136    2.233              585          7.466
# 398          4.308    1.593              614          5.267
#
#                  dates         time  days_of_week direction max_seg_count
# 188  04/25/22-05/24/22  14:30-18:00           m_f   Inbound           722
# 425  04/25/22-05/24/22  14:30-18:00           m_f   Inbound           722
# 198  04/25/22-05/24/22  14:30-18:00           m_f   Inbound           722
# 242  04/25/22-05/24/22  14:30-18:00           m_f   Inbound           722
# 398  04/25/22-05/24/22  14:30-18:00           m_f   Inbound           722
#
# [5 rows x 23 columns]

# %% [markdown]
# MAY OFFPEAK OUTBOUND

# %%
r56_offpeak_may_out=concat_frames_columns(requests.get(URL, params = params_geo_May_offpeak_out, headers = headers), 
                              requests.get(URL, params = params_May_offpeak_out, headers = headers), '04/25/22-05/24/22',
                              '14:30-18:00','m_f','Outbound')

# %%
seg_filter_r56_offpeak_may_out=r56_offpeak_may_out[r56_offpeak_may_out['countForSegment'] > r56_offpeak_may_out['countForSegment'].max()/2]

# %%
clean_geo_r56_offpeak_may_out=seg_filter_r56_offpeak_may_out[seg_filter_r56_offpeak_may_out['percent20Secs']>=np.percentile(seg_filter_r56_offpeak_may_out['percent20Secs'], 80)]

# %%
clean_geo_r56_offpeak_may_out.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 419  LINESTRING (-86.69531 36.30058, -86.69554 36.3...   GALCONSF
# 384  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
# 288  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
# 345  LINESTRING (-86.68661 36.30757, -86.68667 36.3...    GALWMRT
# 374  LINESTRING (-86.68616 36.30781, -86.68639 36.3...    GALWMRT
#
#                        fromStopName  toStopId                      toStopName  \
# 419  Gallatin Pk & Conference Dr Sb  GXIRIVEF               Rivergate Station
# 384           Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 288        Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 345           Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 374           Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed   maxSecs  \
# 419            24.642            412.790489            0.059696  1465.467
# 384            24.481            100.580421            0.243397  1063.067
# 288            24.574             50.863566            0.483136   504.899
# 345            24.481             13.059133            1.874627   648.239
# 374            24.481              8.352079            2.931126    53.195
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 419        777.334  ...        232.614          8.824    2.502
# 384        223.600  ...         22.115          8.803    0.635
# 288        143.640  ...         13.186          3.079    1.662
# 345         20.343  ...          6.967          5.716    0.635
# 374         11.165  ...          6.354          5.324    0.635
#
#      countForSegment  percent20Secs              dates         time  \
# 419              538         29.981  04/25/22-05/24/22  14:30-18:00
# 384              703         16.834  04/25/22-05/24/22  14:30-18:00
# 288              707          7.497  04/25/22-05/24/22  14:30-18:00
# 345              705          6.257  04/25/22-05/24/22  14:30-18:00
# 374              705          5.865  04/25/22-05/24/22  14:30-18:00
#
#      days_of_week direction max_seg_count
# 419           m_f  Outbound           722
# 384           m_f  Outbound           722
# 288           m_f  Outbound           722
# 345           m_f  Outbound           722
# 374           m_f  Outbound           722
#
# [5 rows x 23 columns]

# %% [markdown]
# # APRIL PM PEAK OUBOUND

# %%
r56_pmpeak=concat_frames_columns(requests.get(URL, params = params_geo_April_PMPeak, headers = headers), 
                              requests.get(URL, params = params_April_PMPeak, headers = headers), '03/25/22-04/24/22',
                              '14:30-18:00','m_f','Outbound')

# %%
seg_filter_r56_pmpeak=r56_pmpeak[r56_pmpeak['countForSegment'] > r56_pmpeak['countForSegment'].max()/2]

# %%
clean_geo_r56_pmpeak=seg_filter_r56_pmpeak[seg_filter_r56_pmpeak['percent20Secs']>=np.percentile(seg_filter_r56_pmpeak['percent20Secs'], 80)]

# %%
clean_geo_r56_pmpeak.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 385  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
# 289  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
# 458  LINESTRING (-86.71237 36.26162, -86.71230 36.2...   GALMAPNF
# 661  LINESTRING (-86.71245 36.26140, -86.71237 36.2...   GXOMADWG
# 420  LINESTRING (-86.69531 36.30058, -86.69554 36.3...   GALCONSF
#
#                        fromStopName  toStopId                      toStopName  \
# 385           Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 289        Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 458     Gallatin Pike & Maple St Nb  GALOLDNM  Gallatin Pike & Old Hickory Nb
# 661        Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 420  Gallatin Pk & Conference Dr Sb  GXIRIVEF               Rivergate Station
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed   maxSecs  \
# 385            24.481             49.420050            0.495366   505.975
# 289            24.574             36.781823            0.668102   291.474
# 458            24.282             20.817492            1.166423    85.709
# 661            24.574             23.758418            1.034328   243.571
# 420            24.642            221.206989            0.111398  1201.039
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 385         92.650  ...         21.482          7.921    0.329
# 289         86.288  ...         13.476          4.723    1.666
# 458         46.674  ...          9.638          5.574    1.503
# 661         50.059  ...         10.117          4.918    1.521
# 420        598.173  ...         12.351          3.784    2.111
#
#      countForSegment  percent20Secs              dates         time  \
# 385              417         14.993  03/25/22-04/24/22  14:30-18:00
# 289              430          8.185  03/25/22-04/24/22  14:30-18:00
# 458              427          7.329  03/25/22-04/24/22  14:30-18:00
# 661              426          7.050  03/25/22-04/24/22  14:30-18:00
# 420              282          6.738  03/25/22-04/24/22  14:30-18:00
#
#      days_of_week direction max_seg_count
# 385           m_f  Outbound           444
# 289           m_f  Outbound           444
# 458           m_f  Outbound           444
# 661           m_f  Outbound           444
# 420           m_f  Outbound           444
#
# [5 rows x 23 columns]

# %% [markdown]
# # MAY PM PEAK OUTBOUND

# %%
r56_pmpeak_may=concat_frames_columns(requests.get(URL, params = params_geo_May_APMPeak, headers = headers), 
                              requests.get(URL, params = params_May_PMPeak, headers = headers), '04/25/22-05/24/22',
                              '14:30-18:00','m_f','Outbound')

# %%
seg_filter_r56_pmpeak_may=r56_pmpeak_may[r56_pmpeak_may['countForSegment'] > r56_pmpeak_may['countForSegment'].max()/2]

# %%
clean_geo_r56_pmpeak_may=seg_filter_r56_pmpeak_may[seg_filter_r56_pmpeak_may['percent20Secs']>=np.percentile(seg_filter_r56_pmpeak_may['percent20Secs'], 80)]

# %%
clean_geo_r56_pmpeak_may.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 384  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
# 457  LINESTRING (-86.71237 36.26162, -86.71230 36.2...   GALMAPNF
# 649  LINESTRING (-86.71245 36.26140, -86.71237 36.2...   GXOMADWG
# 288  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
# 344  LINESTRING (-86.68661 36.30757, -86.68667 36.3...    GALWMRT
#
#                     fromStopName  toStopId                      toStopName  \
# 384        Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 457  Gallatin Pike & Maple St Nb  GALOLDNM  Gallatin Pike & Old Hickory Nb
# 649     Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 288     Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 344        Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed   maxSecs  \
# 384            24.481             53.953844            0.453740  1036.192
# 457            24.282             22.273069            1.090196   129.584
# 649            24.574             26.586236            0.924313   206.527
# 288            24.574             37.939133            0.647722   306.111
# 344            24.481             12.044521            2.032542   182.292
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 384        100.078  ...         22.684         10.814    2.565
# 457         49.828  ...         10.090          5.737    2.047
# 649         55.690  ...         10.955          5.394    2.072
# 288         94.981  ...         11.557          3.693    1.548
# 344         20.188  ...          7.054          5.938    2.565
#
#      countForSegment  percent20Secs              dates         time  \
# 384              423         16.951  04/25/22-05/24/22  14:30-18:00
# 457              436          7.844  04/25/22-05/24/22  14:30-18:00
# 649              436          7.803  04/25/22-05/24/22  14:30-18:00
# 288              445          7.388  04/25/22-05/24/22  14:30-18:00
# 344              426          6.468  04/25/22-05/24/22  14:30-18:00
#
#      days_of_week direction max_seg_count
# 384           m_f  Outbound           474
# 457           m_f  Outbound           474
# 649           m_f  Outbound           474
# 288           m_f  Outbound           474
# 344           m_f  Outbound           474
#
# [5 rows x 23 columns]

# %% [markdown]
# # APRIL EVENING INBOUND

# %%
r56_evening_apr=concat_frames_columns(requests.get(URL, params = params_geo_April_Evening_In, headers = headers), 
                              requests.get(URL, params = params_April_Evening_In, headers = headers), '03/25/22-04/24/22',
                              '18:00-23:59','m_f','Inbound')

# %%
seg_filter_r56_evening_apr=r56_evening_apr[r56_evening_apr['countForSegment'] > r56_evening_apr['countForSegment'].max()/2]

# %%
clean_geo_r56_evening_apr=seg_filter_r56_evening_apr[seg_filter_r56_evening_apr['percent20Secs']>=np.percentile(seg_filter_r56_evening_apr['percent20Secs'], 80)]

# %%
clean_geo_r56_evening_apr.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 365  LINESTRING (-86.78159 36.16633, -86.78182 36.1...   JAMGAYWF
# 379  LINESTRING (-86.78135 36.16642, -86.78159 36.1...   JAMGAYWF
# 456  LINESTRING (-86.78111 36.16652, -86.78135 36.1...   JAMGAYWF
# 319  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 431  LINESTRING (-86.78091 36.16663, -86.78111 36.1...   JAMGAYWF
#
#                          fromStopName  toStopId  \
# 365  James Robertson Pkwy & Gay St Wb   MCC4_18
# 379  James Robertson Pkwy & Gay St Wb   MCC4_18
# 456  James Robertson Pkwy & Gay St Wb   MCC4_18
# 319           Madison Station Inbound  GALEMMSN
# 431  James Robertson Pkwy & Gay St Wb   MCC4_18
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 365         Central 4th Ave - Bay 18            23.878             60.288763
# 379         Central 4th Ave - Bay 18            23.878             22.696248
# 456         Central 4th Ave - Bay 18            23.878             12.131694
# 319  S Gallatin Pike & Emmitt Ave Sb            23.806             71.091798
# 431         Central 4th Ave - Bay 18            23.878              6.895176
#
#      averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 365            0.396061  606.267         92.682  ...         30.339
# 379            1.052068  419.719         26.292  ...         15.028
# 456            1.968233  316.747         16.860  ...          7.952
# 319            0.334863  402.900        196.689  ...         10.911
# 431            3.463001  136.954          8.659  ...          5.113
#
#      percent10Secs  minSecs  countForSegment  percent20Secs  \
# 365         12.046    2.401              224         25.633
# 379          7.067    2.401              234         12.919
# 456          4.790    2.401              235          6.288
# 319          2.334    1.119              351          5.522
# 431          3.865    2.401              239          4.720
#
#                  dates         time  days_of_week direction max_seg_count
# 365  03/25/22-04/24/22  18:00-23:59           m_f   Inbound           375
# 379  03/25/22-04/24/22  18:00-23:59           m_f   Inbound           375
# 456  03/25/22-04/24/22  18:00-23:59           m_f   Inbound           375
# 319  03/25/22-04/24/22  18:00-23:59           m_f   Inbound           375
# 431  03/25/22-04/24/22  18:00-23:59           m_f   Inbound           375
#
# [5 rows x 23 columns]

# %% [markdown]
# # MAY EVEING INBOUND

# %%
r56_evening_may=concat_frames_columns(requests.get(URL, params = params_geo_May_Evening_In, headers = headers), 
                              requests.get(URL, params = params_May_Evening_In, headers = headers), '04/25/22-05/24/22',
                              '18:00-23:59','m_f','Inbound')

# %%
seg_filter_r56_evening_may=r56_evening_may[r56_evening_may['countForSegment'] > r56_evening_may['countForSegment'].max()/2]

# %%
clean_geo_r56_evening_may=seg_filter_r56_evening_may[seg_filter_r56_evening_may['percent20Secs']>=np.percentile(seg_filter_r56_evening_may['percent20Secs'], 80)]

# %%
clean_geo_r56_evening_may.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 188  LINESTRING (-86.78159 36.16633, -86.78182 36.1...   JAMGAYWF
# 198  LINESTRING (-86.78135 36.16642, -86.78159 36.1...   JAMGAYWF
# 242  LINESTRING (-86.78111 36.16652, -86.78135 36.1...   JAMGAYWF
# 425  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 227  LINESTRING (-86.78091 36.16663, -86.78111 36.1...   JAMGAYWF
#
#                          fromStopName  toStopId  \
# 188  James Robertson Pkwy & Gay St Wb   MCC4_18
# 198  James Robertson Pkwy & Gay St Wb   MCC4_18
# 242  James Robertson Pkwy & Gay St Wb   MCC4_18
# 425           Madison Station Inbound  GALEMMSN
# 227  James Robertson Pkwy & Gay St Wb   MCC4_18
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 188         Central 4th Ave - Bay 18            23.878             63.869135
# 198         Central 4th Ave - Bay 18            23.878             28.731100
# 242         Central 4th Ave - Bay 18            23.878             12.333532
# 425  S Gallatin Pike & Emmitt Ave Sb            23.895             69.242237
# 227         Central 4th Ave - Bay 18            23.878              9.144311
#
#      averageTravelSpeed   maxSecs  percent90Secs  ...  percent30Secs  \
# 188            0.373858   535.122        109.421  ...         30.837
# 198            0.831085  1039.952         28.231  ...         15.138
# 242            1.936023   140.794         18.215  ...          8.375
# 425            0.345093   290.931        183.352  ...         13.510
# 227            2.611241   319.197          9.932  ...          5.593
#
#      percent10Secs  minSecs  countForSegment  percent20Secs  \
# 188         11.480    2.277              289         25.842
# 198          6.525    2.277              310         12.336
# 242          4.825    2.277              314          6.829
# 425          2.517    1.029              346          5.787
# 227          3.969    2.277              318          4.986
#
#                  dates         time  days_of_week direction max_seg_count
# 188  04/25/22-05/24/22  18:00-23:59           m_f   Inbound           390
# 198  04/25/22-05/24/22  18:00-23:59           m_f   Inbound           390
# 242  04/25/22-05/24/22  18:00-23:59           m_f   Inbound           390
# 425  04/25/22-05/24/22  18:00-23:59           m_f   Inbound           390
# 227  04/25/22-05/24/22  18:00-23:59           m_f   Inbound           390
#
# [5 rows x 23 columns]

# %% [markdown]
# # APRIL EVENING OUTBOUND

# %%
r56_evening_apr_out=concat_frames_columns(requests.get(URL, params = params_geo_April_Evening_out, headers = headers), 
                              requests.get(URL, params = params_April_Evening_out, headers = headers), '03/25/22-04/24/22',
                              '18:00-23:59','m_f','Outbound')
r56_evening_apr_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              2.912487
# 1         Inglewood Station Outbound            24.831              1.775117
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0            8.374286   35.059          5.579  ...          1.423
# 1           13.988374    5.434          2.205  ...          1.557
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.264    0.841              464          1.348  03/25/22-04/24/22
# 1          1.384    0.981              429          1.487  03/25/22-04/24/22
#
#           time  days_of_week direction max_seg_count
# 0  18:00-23:59           m_f  Outbound           491
# 1  18:00-23:59           m_f  Outbound           491
#
# [2 rows x 23 columns]

# %%
seg_filter_r56_evening_apr_out=r56_evening_apr_out[r56_evening_apr_out['countForSegment'] > r56_evening_apr_out['countForSegment'].max()/2]
seg_filter_r56_evening_apr_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              2.912487
# 1         Inglewood Station Outbound            24.831              1.775117
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0            8.374286   35.059          5.579  ...          1.423
# 1           13.988374    5.434          2.205  ...          1.557
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.264    0.841              464          1.348  03/25/22-04/24/22
# 1          1.384    0.981              429          1.487  03/25/22-04/24/22
#
#           time  days_of_week direction max_seg_count
# 0  18:00-23:59           m_f  Outbound           491
# 1  18:00-23:59           m_f  Outbound           491
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_evening_apr_out=seg_filter_r56_evening_apr_out[seg_filter_r56_evening_apr_out['percent20Secs']>=np.percentile(seg_filter_r56_evening_apr_out['percent20Secs'], 80)]
clean_geo_r56_evening_apr_out.head(2)
# Out:
#                                              geometry fromStopId  \
# 4   LINESTRING (-86.76508 36.17290, -86.76483 36.1...    JAM2AEF
# 15  LINESTRING (-86.76483 36.17299, -86.76458 36.1...    JAM2AEF
#
#                            fromStopName  toStopId             toStopName  \
# 4   James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
# 15  James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
#
#     pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 4             24.726              2.745988            9.004409   15.032
# 15            24.726              2.580728            9.581017    9.334
#
#     percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 4           4.442  ...          1.976          1.667    1.068
# 15          3.613  ...          2.029          1.710    1.068
#
#     countForSegment  percent20Secs              dates         time  \
# 4               405          1.854  03/25/22-04/24/22  18:00-23:59
# 15              405          1.897  03/25/22-04/24/22  18:00-23:59
#
#     days_of_week direction max_seg_count
# 4            m_f  Outbound           491
# 15           m_f  Outbound           491
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_evening_apr_out.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 385  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
# 289  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
# 345  LINESTRING (-86.68661 36.30757, -86.68667 36.3...    GALWMRT
# 360  LINESTRING (-86.68639 36.30769, -86.68661 36.3...    GALWMRT
# 375  LINESTRING (-86.68616 36.30781, -86.68639 36.3...    GALWMRT
#
#                  fromStopName  toStopId                      toStopName  \
# 385     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 289  Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 345     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 360     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 375     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 385            24.481             52.059729            0.470248  593.618
# 289            24.574             44.154371            0.556547  440.867
# 345            24.481             12.632071            1.938004  375.282
# 360            24.481             16.619708            1.473010  775.142
# 375            24.481             10.091173            2.425982  412.786
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 385        106.495  ...         15.861          5.036    0.300
# 289        131.229  ...         11.274          2.753    1.211
# 345         20.052  ...          6.699          5.586    0.300
# 360         10.956  ...          6.050          5.041    0.300
# 375         12.036  ...          6.078          5.041    0.300
#
#      countForSegment  percent20Secs              dates         time  \
# 385              487          7.503  03/25/22-04/24/22  18:00-23:59
# 289              448          6.602  03/25/22-04/24/22  18:00-23:59
# 345              490          6.133  03/25/22-04/24/22  18:00-23:59
# 360              490          5.697  03/25/22-04/24/22  18:00-23:59
# 375              490          5.697  03/25/22-04/24/22  18:00-23:59
#
#      days_of_week direction max_seg_count
# 385           m_f  Outbound           491
# 289           m_f  Outbound           491
# 345           m_f  Outbound           491
# 360           m_f  Outbound           491
# 375           m_f  Outbound           491
#
# [5 rows x 23 columns]

# %% [markdown]
# # MAY EVENING OUBOUND

# %%
r56_evening_may_out=concat_frames_columns(requests.get(URL, params = params_geo_May_Evening_out, headers = headers), 
                              requests.get(URL, params = params_May_Evening_out, headers = headers), '04/25/22-05/24/22',
                              '18:00-23:59','m_f','Outbound')
r56_evening_may_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              3.063004
# 1         Inglewood Station Outbound            24.831              1.765641
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0            7.962771   33.155          6.241  ...          1.407
# 1           14.063448   19.066          2.124  ...          1.531
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.234    0.908              473          1.335  04/25/22-05/24/22
# 1          1.402    1.153              435          1.469  04/25/22-05/24/22
#
#           time  days_of_week direction max_seg_count
# 0  18:00-23:59           m_f  Outbound           507
# 1  18:00-23:59           m_f  Outbound           507
#
# [2 rows x 23 columns]

# %%
seg_filter_r56_evening_may_out=r56_evening_may_out[r56_evening_may_out['countForSegment'] > r56_evening_may_out['countForSegment'].max()/2]
seg_filter_r56_evening_may_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              3.063004
# 1         Inglewood Station Outbound            24.831              1.765641
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0            7.962771   33.155          6.241  ...          1.407
# 1           14.063448   19.066          2.124  ...          1.531
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.234    0.908              473          1.335  04/25/22-05/24/22
# 1          1.402    1.153              435          1.469  04/25/22-05/24/22
#
#           time  days_of_week direction max_seg_count
# 0  18:00-23:59           m_f  Outbound           507
# 1  18:00-23:59           m_f  Outbound           507
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_evening_may_out=seg_filter_r56_evening_may_out[seg_filter_r56_evening_may_out['percent20Secs']>=np.percentile(seg_filter_r56_evening_may_out['percent20Secs'], 80)]
clean_geo_r56_evening_may_out.head(2)
# Out:
#                                              geometry fromStopId  \
# 15  LINESTRING (-86.76483 36.17299, -86.76458 36.1...    JAM2AEF
# 23  LINESTRING (-86.76458 36.17309, -86.76433 36.1...    JAM2AEF
#
#                            fromStopName  toStopId             toStopName  \
# 15  James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
# 23  James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
#
#     pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 15            24.726              2.501621            9.883991   10.091
# 23            24.726              2.522576            9.801885    5.396
#
#     percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 15          3.631  ...          1.981          1.702    1.184
# 23          3.673  ...          2.030          1.724    1.184
#
#     countForSegment  percent20Secs              dates         time  \
# 15              420          1.827  04/25/22-05/24/22  18:00-23:59
# 23              420          1.875  04/25/22-05/24/22  18:00-23:59
#
#     days_of_week direction max_seg_count
# 15           m_f  Outbound           507
# 23           m_f  Outbound           507
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_evening_may_out.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 384  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
# 344  LINESTRING (-86.68661 36.30757, -86.68667 36.3...    GALWMRT
# 288  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
# 374  LINESTRING (-86.68616 36.30781, -86.68639 36.3...    GALWMRT
# 359  LINESTRING (-86.68639 36.30769, -86.68661 36.3...    GALWMRT
#
#                  fromStopName  toStopId                      toStopName  \
# 384     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 344     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 288  Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 374     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 359     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 384            24.481             46.744386            0.523721  995.119
# 344            24.481             16.046427            1.525636  552.057
# 288            24.574             42.690912            0.575626  279.351
# 374            24.481              8.702089            2.813233   86.971
# 359            24.481             14.078079            1.738945  629.013
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 384         97.094  ...         15.693          5.285    0.870
# 344         21.608  ...          6.798          5.481    3.161
# 288        122.858  ...         10.590          3.002    1.450
# 374         12.261  ...          6.267          5.182    0.870
# 359         11.213  ...          5.996          4.945    0.870
#
#      countForSegment  percent20Secs              dates         time  \
# 384              503          9.594  04/25/22-05/24/22  18:00-23:59
# 344              506          6.066  04/25/22-05/24/22  18:00-23:59
# 288              453          5.935  04/25/22-05/24/22  18:00-23:59
# 374              506          5.747  04/25/22-05/24/22  18:00-23:59
# 359              506          5.556  04/25/22-05/24/22  18:00-23:59
#
#      days_of_week direction max_seg_count
# 384           m_f  Outbound           507
# 344           m_f  Outbound           507
# 288           m_f  Outbound           507
# 374           m_f  Outbound           507
# 359           m_f  Outbound           507
#
# [5 rows x 23 columns]

# %% [markdown]
# # EARLY AM INBOUND

# %%
r56_earlyam_april_in=concat_frames_columns(requests.get(URL, params = params_geo_April_EarlyAM_In, headers = headers), 
                              requests.get(URL, params = params_April_EarlyAM_In, headers = headers), '03/25/22-04/24/22',
                              '00:00-06:00','m_f','Inbound')
r56_earlyam_april_in.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70083 36.29509, -86.70098 36.2...   GXIMYASF
# 1  LINESTRING (-86.71756 36.25213, -86.71770 36.2...   GALEMMSN
#
#                       fromStopName  toStopId                       toStopName  \
# 0            Myatt Station Inbound  GALALLSN  N Gallatin Pk & Alta Loma Rd Sb
# 1  S Gallatin Pike & Emmitt Ave Sb  GXIDUESN         Due West Station Inbound
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.437              2.256683           10.385597    6.242
# 1            24.651              1.983803           12.426133   13.019
#
#    percent90Secs  ...  percent30Secs  percent10Secs  minSecs  countForSegment  \
# 0          3.336  ...          1.697          1.524    1.352              126
# 1          2.394  ...          1.703          1.510    1.291              117
#
#    percent20Secs              dates         time  days_of_week direction  \
# 0          1.642  03/25/22-04/24/22  00:00-06:00           m_f   Inbound
# 1          1.594  03/25/22-04/24/22  00:00-06:00           m_f   Inbound
#
#   max_seg_count
# 0           136
# 1           136
#
# [2 rows x 23 columns]

# %%
seg_filter_r56_earlyam_april_in=r56_earlyam_april_in[r56_earlyam_april_in['countForSegment'] > r56_earlyam_april_in['countForSegment'].max()/2]
seg_filter_r56_earlyam_april_in.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70083 36.29509, -86.70098 36.2...   GXIMYASF
# 1  LINESTRING (-86.71756 36.25213, -86.71770 36.2...   GALEMMSN
#
#                       fromStopName  toStopId                       toStopName  \
# 0            Myatt Station Inbound  GALALLSN  N Gallatin Pk & Alta Loma Rd Sb
# 1  S Gallatin Pike & Emmitt Ave Sb  GXIDUESN         Due West Station Inbound
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.437              2.256683           10.385597    6.242
# 1            24.651              1.983803           12.426133   13.019
#
#    percent90Secs  ...  percent30Secs  percent10Secs  minSecs  countForSegment  \
# 0          3.336  ...          1.697          1.524    1.352              126
# 1          2.394  ...          1.703          1.510    1.291              117
#
#    percent20Secs              dates         time  days_of_week direction  \
# 0          1.642  03/25/22-04/24/22  00:00-06:00           m_f   Inbound
# 1          1.594  03/25/22-04/24/22  00:00-06:00           m_f   Inbound
#
#   max_seg_count
# 0           136
# 1           136
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_april_in=seg_filter_r56_earlyam_april_in[seg_filter_r56_earlyam_april_in['percent20Secs']>=np.percentile(seg_filter_r56_earlyam_april_in['percent20Secs'], 80)]
clean_geo_r56_earlyam_april_in.head(2)
# Out:
#                                             geometry fromStopId  \
# 3  LINESTRING (-86.69581 36.30031, -86.69603 36.3...   GXIRIVEF
# 5  LINESTRING (-86.75448 36.17705, -86.75473 36.1...   GXIFIVEN
#
#                   fromStopName  toStopId                 toStopName  \
# 3            Rivergate Station  GXIMYASF      Myatt Station Inbound
# 5  Five Points Station Inbound  MAIMCFWN  Main St & Mcferrin Ave Wb
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 3            24.748              3.249787            7.615268   11.535
# 5            24.785              2.498705            9.919138    5.441
#
#    percent90Secs  ...  percent30Secs  percent10Secs  minSecs  countForSegment  \
# 3          6.358  ...          2.032          1.580    0.890              136
# 5          3.971  ...          1.989          1.772    1.505               78
#
#    percent20Secs              dates         time  days_of_week direction  \
# 3          1.822  03/25/22-04/24/22  00:00-06:00           m_f   Inbound
# 5          1.863  03/25/22-04/24/22  00:00-06:00           m_f   Inbound
#
#   max_seg_count
# 3           136
# 5           136
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_april_in.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 319  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 256  LINESTRING (-86.75729 36.17597, -86.75752 36.1...   MAIMCFWN
# 705  LINESTRING (-86.71982 36.24883, -86.71994 36.2...   GXIDUESN
# 394  LINESTRING (-86.71404 36.25718, -86.71412 36.2...   GXIMADLB
# 474  LINESTRING (-86.75752 36.17588, -86.75777 36.1...   GXI7AVEN
#
#                     fromStopName  toStopId                       toStopName  \
# 319      Madison Station Inbound  GALEMMSN  S Gallatin Pike & Emmitt Ave Sb
# 256    Main St & Mcferrin Ave Wb  GXI7AVEN      Main Street Station Inbound
# 705     Due West Station Inbound  GALBERWF  S Gallatin Pike & Berkley Dr Sb
# 394      Madison Station Inbound  GALEMMSN  S Gallatin Pike & Emmitt Ave Sb
# 474  Main Street Station Inbound  MAI5STWN              Main St & 5th St Wb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 319            23.806             83.166796            0.286244  363.507
# 256            22.655             14.817867            1.528898   67.477
# 705            23.544             16.734630            1.406903   55.065
# 394            23.806              5.276800            4.511446   12.451
# 474            24.565              6.911840            3.554046   85.844
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 319        218.622  ...         23.212          2.261    1.388
# 256         27.959  ...          7.009          1.706    1.188
# 705         33.850  ...          7.507          1.973    1.351
# 394          9.445  ...          3.554          2.321    1.388
# 474         11.897  ...          2.929          1.818    1.289
#
#      countForSegment  percent20Secs              dates         time  \
# 319              113          9.227  03/25/22-04/24/22  00:00-06:00
# 256               75          4.216  03/25/22-04/24/22  00:00-06:00
# 705              108          3.850  03/25/22-04/24/22  00:00-06:00
# 394              115          2.927  03/25/22-04/24/22  00:00-06:00
# 474               75          2.574  03/25/22-04/24/22  00:00-06:00
#
#      days_of_week direction max_seg_count
# 319           m_f   Inbound           136
# 256           m_f   Inbound           136
# 705           m_f   Inbound           136
# 394           m_f   Inbound           136
# 474           m_f   Inbound           136
#
# [5 rows x 23 columns]

# %% [markdown]
# # MAY EARLY AM INBOUND

# %%
r56_earlyam_may_in=concat_frames_columns(requests.get(URL, params = params_geo_May_EarlyAM_In, headers = headers), 
                              requests.get(URL, params = params_May_EarlyAM_In, headers = headers), '04/25/22-05/24/22',
                              '00:00-06:00','m_f','Inbound')
r56_earlyam_may_in.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.73946 36.20187, -86.73957 36.2...   GXIEHILF
# 1  LINESTRING (-86.77859 36.16773, -86.77882 36.1...   JAMGAYWF
#
#                        fromStopName  toStopId                  toStopName  \
# 0         East Hill Station Inbound  GALBURSN  Gallatin Pk & Burchwood Av
# 1  James Robertson Pkwy & Gay St Wb   MCC4_18    Central 4th Ave - Bay 18
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.949              1.860189           12.874498    3.713
# 1            23.878              2.415629            9.884796    5.147
#
#    percent90Secs  ...  percent30Secs  percent10Secs  minSecs  countForSegment  \
# 0          2.415  ...          1.647          1.426    1.144              106
# 1          3.679  ...          1.904          1.629    1.249               89
#
#    percent20Secs              dates         time  days_of_week direction  \
# 0          1.566  04/25/22-05/24/22  00:00-06:00           m_f   Inbound
# 1          1.804  04/25/22-05/24/22  00:00-06:00           m_f   Inbound
#
#   max_seg_count
# 0           143
# 1           143
#
# [2 rows x 23 columns]

# %%
seg_filter_r56_earlyam_may_in=r56_earlyam_may_in[r56_earlyam_may_in['countForSegment'] > r56_earlyam_may_in['countForSegment'].max()/2]
seg_filter_r56_earlyam_may_in.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.73946 36.20187, -86.73957 36.2...   GXIEHILF
# 1  LINESTRING (-86.77859 36.16773, -86.77882 36.1...   JAMGAYWF
#
#                        fromStopName  toStopId                  toStopName  \
# 0         East Hill Station Inbound  GALBURSN  Gallatin Pk & Burchwood Av
# 1  James Robertson Pkwy & Gay St Wb   MCC4_18    Central 4th Ave - Bay 18
#
#    pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 0            23.949              1.860189           12.874498    3.713
# 1            23.878              2.415629            9.884796    5.147
#
#    percent90Secs  ...  percent30Secs  percent10Secs  minSecs  countForSegment  \
# 0          2.415  ...          1.647          1.426    1.144              106
# 1          3.679  ...          1.904          1.629    1.249               89
#
#    percent20Secs              dates         time  days_of_week direction  \
# 0          1.566  04/25/22-05/24/22  00:00-06:00           m_f   Inbound
# 1          1.804  04/25/22-05/24/22  00:00-06:00           m_f   Inbound
#
#   max_seg_count
# 0           143
# 1           143
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_may_in=seg_filter_r56_earlyam_may_in[seg_filter_r56_earlyam_may_in['percent20Secs']>=np.percentile(seg_filter_r56_earlyam_may_in['percent20Secs'], 80)]
clean_geo_r56_earlyam_may_in.head(2)
# Out:
#                                              geometry fromStopId  \
# 1   LINESTRING (-86.77859 36.16773, -86.77882 36.1...   JAMGAYWF
# 21  LINESTRING (-86.77882 36.16763, -86.77906 36.1...   JAMGAYWF
#
#                         fromStopName toStopId                toStopName  \
# 1   James Robertson Pkwy & Gay St Wb  MCC4_18  Central 4th Ave - Bay 18
# 21  James Robertson Pkwy & Gay St Wb  MCC4_18  Central 4th Ave - Bay 18
#
#     pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 1             23.878              2.415629            9.884796    5.147
# 21            23.878              2.693256            8.865849    9.299
#
#     percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 1           3.679  ...          1.904          1.629    1.249
# 21          4.529  ...          1.952          1.707    1.249
#
#     countForSegment  percent20Secs              dates         time  \
# 1                89          1.804  04/25/22-05/24/22  00:00-06:00
# 21               90          1.857  04/25/22-05/24/22  00:00-06:00
#
#     days_of_week direction max_seg_count
# 1            m_f   Inbound           143
# 21           m_f   Inbound           143
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_may_in.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 198  LINESTRING (-86.78135 36.16642, -86.78159 36.1...   JAMGAYWF
# 425  LINESTRING (-86.71397 36.25739, -86.71404 36.2...   GXIMADLB
# 242  LINESTRING (-86.78111 36.16652, -86.78135 36.1...   JAMGAYWF
# 402  LINESTRING (-86.71982 36.24883, -86.71994 36.2...   GXIDUESN
# 227  LINESTRING (-86.78091 36.16663, -86.78111 36.1...   JAMGAYWF
#
#                          fromStopName  toStopId  \
# 198  James Robertson Pkwy & Gay St Wb   MCC4_18
# 425           Madison Station Inbound  GALEMMSN
# 242  James Robertson Pkwy & Gay St Wb   MCC4_18
# 402          Due West Station Inbound  GALBERWF
# 227  James Robertson Pkwy & Gay St Wb   MCC4_18
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 198         Central 4th Ave - Bay 18            23.878             37.103090
# 425  S Gallatin Pike & Emmitt Ave Sb            23.895             85.833718
# 242         Central 4th Ave - Bay 18            23.878             16.408423
# 402  S Gallatin Pike & Berkley Dr Sb            23.544             17.978527
# 227         Central 4th Ave - Bay 18            23.878              9.870200
#
#      averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 198            0.643558  553.248         89.318  ...         14.419
# 425            0.278387  347.206        220.535  ...         26.217
# 242            1.455228  291.744         15.585  ...          8.197
# 402            1.309562   72.597         36.431  ...          9.620
# 227            2.419201  305.679          8.197  ...          5.046
#
#      percent10Secs  minSecs  countForSegment  percent20Secs  \
# 198         10.314    2.837               78         13.513
# 425          4.049    1.748              117         13.090
# 242          5.189    2.837               78          7.116
# 402          2.425    1.518              110          5.453
# 227          3.819    2.837               80          4.741
#
#                  dates         time  days_of_week direction max_seg_count
# 198  04/25/22-05/24/22  00:00-06:00           m_f   Inbound           143
# 425  04/25/22-05/24/22  00:00-06:00           m_f   Inbound           143
# 242  04/25/22-05/24/22  00:00-06:00           m_f   Inbound           143
# 402  04/25/22-05/24/22  00:00-06:00           m_f   Inbound           143
# 227  04/25/22-05/24/22  00:00-06:00           m_f   Inbound           143
#
# [5 rows x 23 columns]

# %% [markdown]
# # APRIL EARLY AM OUTBOUND

# %%
r56_earlyam_apr_out=concat_frames_columns(requests.get(URL, params = params_geo_April_EarlyAM_out, headers = headers), 
                              requests.get(URL, params = params_April_EarlyAM_out, headers = headers), '03/25/22-04/24/22',
                              '00:00-06:00','m_f','Outbound')
r56_earlyam_apr_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              1.879417
# 1         Inglewood Station Outbound            24.831              1.685717
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0           12.977429    5.061          3.453  ...          1.331
# 1           14.730231    2.236          1.968  ...          1.594
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.104    0.967               48          1.225  03/25/22-04/24/22
# 1          1.387    1.168               60          1.505  03/25/22-04/24/22
#
#           time  days_of_week direction max_seg_count
# 0  00:00-06:00           m_f  Outbound            67
# 1  00:00-06:00           m_f  Outbound            67
#
# [2 rows x 23 columns]

# %%
seg_filter_r56_earlyam_apr_out=r56_earlyam_apr_out[r56_earlyam_apr_out['countForSegment'] > r56_earlyam_apr_out['countForSegment'].max()/2]
seg_filter_r56_earlyam_apr_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              1.879417
# 1         Inglewood Station Outbound            24.831              1.685717
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0           12.977429    5.061          3.453  ...          1.331
# 1           14.730231    2.236          1.968  ...          1.594
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.104    0.967               48          1.225  03/25/22-04/24/22
# 1          1.387    1.168               60          1.505  03/25/22-04/24/22
#
#           time  days_of_week direction max_seg_count
# 0  00:00-06:00           m_f  Outbound            67
# 1  00:00-06:00           m_f  Outbound            67
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_apr_out=seg_filter_r56_earlyam_apr_out[seg_filter_r56_earlyam_apr_out['percent20Secs']>=np.percentile(seg_filter_r56_earlyam_apr_out['percent20Secs'], 80)]
clean_geo_r56_earlyam_apr_out.head(2)
# Out:
#                                              geometry fromStopId  \
# 4   LINESTRING (-86.76508 36.17290, -86.76483 36.1...    JAM2AEF
# 15  LINESTRING (-86.76483 36.17299, -86.76458 36.1...    JAM2AEF
#
#                            fromStopName  toStopId             toStopName  \
# 4   James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
# 15  James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
#
#     pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 4             24.726              2.383860           10.372253    6.253
# 15            24.726              2.248579           10.996278    5.074
#
#     percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 4           3.988  ...          1.766          1.634     1.43
# 15          3.190  ...          1.815          1.644     1.43
#
#     countForSegment  percent20Secs              dates         time  \
# 4                57          1.691  03/25/22-04/24/22  00:00-06:00
# 15               57          1.734  03/25/22-04/24/22  00:00-06:00
#
#     days_of_week direction max_seg_count
# 4            m_f  Outbound            67
# 15           m_f  Outbound            67
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_apr_out.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 288  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
# 344  LINESTRING (-86.68661 36.30757, -86.68667 36.3...    GALWMRT
# 374  LINESTRING (-86.68616 36.30781, -86.68639 36.3...    GALWMRT
# 359  LINESTRING (-86.68639 36.30769, -86.68661 36.3...    GALWMRT
# 384  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
#
#                  fromStopName  toStopId                      toStopName  \
# 288  Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
# 344     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 374     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 359     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 384     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 288            24.574            107.122854            0.229400  392.297
# 344            24.481             11.836918            2.068190   95.366
# 374            24.481              7.376143            3.318943   18.629
# 359            24.481              8.074469            3.031902   67.631
# 384            24.481             37.991646            0.644379  274.352
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 288        226.600  ...         47.414          3.907    2.068
# 344         24.853  ...          5.492          3.929    3.343
# 374         12.634  ...          4.927          3.702    3.512
# 359         11.089  ...          5.234          3.970    3.554
# 384        105.873  ...          4.954          3.505    3.228
#
#      countForSegment  percent20Secs              dates         time  \
# 288               48         30.766  03/25/22-04/24/22  00:00-06:00
# 344               49          4.622  03/25/22-04/24/22  00:00-06:00
# 374               49          4.242  03/25/22-04/24/22  00:00-06:00
# 359               49          4.242  03/25/22-04/24/22  00:00-06:00
# 384               48          3.856  03/25/22-04/24/22  00:00-06:00
#
#      days_of_week direction max_seg_count
# 288           m_f  Outbound            67
# 344           m_f  Outbound            67
# 374           m_f  Outbound            67
# 359           m_f  Outbound            67
# 384           m_f  Outbound            67
#
# [5 rows x 23 columns]

# %% [markdown]
# # MAY EARLY AM OUTBOUND

# %%
r56_earlyam_may_out=concat_frames_columns(requests.get(URL, params = params_geo_May_EarlyAM_out, headers = headers), 
                              requests.get(URL, params = params_May_EarlyAM_out, headers = headers), '04/25/22-05/24/22',
                              '00:00-06:00','m_f','Outbound')
r56_earlyam_may_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              1.667275
# 1         Inglewood Station Outbound            24.831              1.550014
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0           14.628661    5.891          2.400  ...          1.274
# 1           16.019855    2.214          1.835  ...          1.424
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.038    0.946               51          1.225  04/25/22-05/24/22
# 1          1.283    1.093               73          1.349  04/25/22-05/24/22
#
#           time  days_of_week direction max_seg_count
# 0  00:00-06:00           m_f  Outbound            76
# 1  00:00-06:00           m_f  Outbound            76
#
# [2 rows x 23 columns]

# %%
seg_filter_r56_earlyam_may_out=r56_earlyam_may_out[r56_earlyam_may_out['countForSegment'] > r56_earlyam_may_out['countForSegment'].max()/2]
seg_filter_r56_earlyam_may_out.head(2)
# Out:
#                                             geometry fromStopId  \
# 0  LINESTRING (-86.70239 36.29300, -86.70226 36.2...   GALEDENN
# 1  LINESTRING (-86.72566 36.22324, -86.72564 36.2...   GALARDNN
#
#                      fromStopName  toStopId  \
# 0  Gallatin Pike & Edenwold Rd Nb  GALALTNF
# 1  N Gallatin Pike & Ardee Ave Nb  GXOINGLN
#
#                           toStopName  pathLengthMeters  averageTravelSeconds  \
# 0  N Gallatin Pike & Alta Loma Rd Nb            24.390              1.667275
# 1         Inglewood Station Outbound            24.831              1.550014
#
#    averageTravelSpeed  maxSecs  percent90Secs  ...  percent30Secs  \
# 0           14.628661    5.891          2.400  ...          1.274
# 1           16.019855    2.214          1.835  ...          1.424
#
#    percent10Secs  minSecs  countForSegment  percent20Secs              dates  \
# 0          1.038    0.946               51          1.225  04/25/22-05/24/22
# 1          1.283    1.093               73          1.349  04/25/22-05/24/22
#
#           time  days_of_week direction max_seg_count
# 0  00:00-06:00           m_f  Outbound            76
# 1  00:00-06:00           m_f  Outbound            76
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_may_out=seg_filter_r56_earlyam_may_out[seg_filter_r56_earlyam_may_out['percent20Secs']>=np.percentile(seg_filter_r56_earlyam_may_out['percent20Secs'], 80)]
clean_geo_r56_earlyam_may_out.head(2)
# Out:
#                                              geometry fromStopId  \
# 4   LINESTRING (-86.76508 36.17290, -86.76483 36.1...    JAM2AEF
# 15  LINESTRING (-86.76483 36.17299, -86.76458 36.1...    JAM2AEF
#
#                            fromStopName  toStopId             toStopName  \
# 4   James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
# 15  James Robertson Pkwy & 2nd Ave N Eb  MAIS6SEN  Main St & S 6th St Eb
#
#     pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 4             24.726              2.632915            9.391112    9.289
# 15            24.726              2.359915           10.477496    7.564
#
#     percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 4           4.342  ...          1.775          1.606    1.491
# 15          3.599  ...          1.764          1.607    1.491
#
#     countForSegment  percent20Secs              dates         time  \
# 4                59          1.690  04/25/22-05/24/22  00:00-06:00
# 15               59          1.721  04/25/22-05/24/22  00:00-06:00
#
#     days_of_week direction max_seg_count
# 4            m_f  Outbound            76
# 15           m_f  Outbound            76
#
# [2 rows x 23 columns]

# %%
clean_geo_r56_earlyam_may_out.sort_values(by=('percent20Secs'), ascending=False).head()
# Out:
#                                               geometry fromStopId  \
# 343  LINESTRING (-86.68661 36.30757, -86.68667 36.3...    GALWMRT
# 358  LINESTRING (-86.68639 36.30769, -86.68661 36.3...    GALWMRT
# 373  LINESTRING (-86.68616 36.30781, -86.68639 36.3...    GALWMRT
# 383  LINESTRING (-86.68593 36.30793, -86.68616 36.3...    GALWMRT
# 288  LINESTRING (-86.71419 36.25652, -86.71411 36.2...   GXOMADWG
#
#                  fromStopName  toStopId                      toStopName  \
# 343     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 358     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 373     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 383     Walmart Gallatin Pike  GALCONSF  Gallatin Pk & Conference Dr Sb
# 288  Madison Station Outbound  GALMAPNF     Gallatin Pike & Maple St Nb
#
#      pathLengthMeters  averageTravelSeconds  averageTravelSpeed  maxSecs  \
# 343            24.481             13.137474            1.863448   65.028
# 358            24.481             10.127053            2.417386   94.512
# 373            24.481              7.477333            3.274028   28.090
# 383            24.481             25.052772            0.977177  181.420
# 288            24.574             78.621389            0.312561  297.087
#
#      percent90Secs  ...  percent30Secs  percent10Secs  minSecs  \
# 343         31.424  ...          5.969          4.324    0.283
# 358         13.198  ...          5.106          3.883    0.283
# 373         13.092  ...          5.106          3.824    0.283
# 383         82.184  ...          5.595          3.883    0.283
# 288        191.323  ...         13.407          1.877    1.318
#
#      countForSegment  percent20Secs              dates         time  \
# 343               57          4.829  04/25/22-05/24/22  00:00-06:00
# 358               57          4.702  04/25/22-05/24/22  00:00-06:00
# 373               57          4.688  04/25/22-05/24/22  00:00-06:00
# 383               57          4.676  04/25/22-05/24/22  00:00-06:00
# 288               54          4.449  04/25/22-05/24/22  00:00-06:00
#
#      days_of_week direction max_seg_count
# 343           m_f  Outbound            76
# 358           m_f  Outbound            76
# 373           m_f  Outbound            76
# 383           m_f  Outbound            76
# 288           m_f  Outbound            76
#
# [5 rows x 23 columns]
