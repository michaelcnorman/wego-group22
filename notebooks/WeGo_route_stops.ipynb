# %%
pip install sodapy
# Out:
# Requirement already satisfied: sodapy in c:\users\vital\anaconda3\envs\geospatial\lib\site-packages (2.1.1)
# Requirement already satisfied: requests>=2.20.0 in c:\users\vital\anaconda3\envs\geospatial\lib\site-packages (from sodapy) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vital\anaconda3\envs\geospatial\lib\site-packages (from requests>=2.20.0->sodapy) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vital\anaconda3\envs\geospatial\lib\site-packages (from requests>=2.20.0->sodapy) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vital\anaconda3\envs\geospatial\lib\site-packages (from requests>=2.20.0->sodapy) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vital\anaconda3\envs\geospatial\lib\site-packages (from requests>=2.20.0->sodapy) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sodapy import Socrata

# %%
from shapely.geometry import Point
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
client = Socrata("data.nashville.gov", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("vfe9-k7vc", limit=5000)

# %%
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#      stop_id_number stop_abbreviation                              stopname  \
# 0              5120          7AVUNINN                 7TH AVE & UNION ST NB
# 1              5455             CM5_4                       Temporary Bay 4
# 2              2762          23ACLASF      23RD AVE N & CLARKSVILLE PIKE SB
# 3              4079          21ACHUSN             21ST AVE N & CHURCH ST SB
# 4              4133           GRWHIWN       GREEN LN & WHITES CREEK PIKE WB
# ...             ...               ...                                   ...
# 2573           5166          JEF6AVWM             JEFFERSON ST & 6TH AVE WB
# 2574           4698          NEEJAPEF     NEELY'S BEND RD & JASPERSON DR EB
# 2575           4700          NEEALLEN       NEELY'S BEND RD & ALLEN PASS EB
# 2576           4714          OLDFORWN  OLD HICKORY BLVD & FOREST PARK RD WB
# 2577           1940          THOEIREF            THOMPSON LN & EAST IRIS DR
#
#       shelter  bench                 route_name route_number  \
# 0       False  False  AIRPORT - DOWNTOWN HOTELS          NaN
# 1       False  False                     HERMAN          NaN
# 2       False  False                   BORDEAUX           22
# 3       False   True                    MIDTOWN           25
# 4       False  False              GOLDEN VALLEY           41
# ...       ...    ...                        ...          ...
# 2573    False  False    MUSIC CITY BLUE CIRCUIT           60
# 2574    False  False          MADISON CONNECTOR           76
# 2575    False  False          MADISON CONNECTOR          NaN
# 2576    False  False          MADISON CONNECTOR           76
# 2577    False  False         THOMPSON CONNECTOR           77
#
#                                         geocoded_column  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     {'latitude': '36.236249', 'longitude': '-86.81...
# ...                                                 ...
# 2573  {'latitude': '36.173796', 'longitude': '-86.78...
# 2574  {'latitude': '36.247943', 'longitude': '-86.68...
# 2575                                                NaN
# 2576  {'latitude': '36.263003', 'longitude': '-86.70...
# 2577  {'latitude': '36.111799', 'longitude': '-86.76...
#
#      :@computed_region_p6sk_2acq :@computed_region_gxvr_9jxz  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                             16                           6
# ...                          ...                         ...
# 2573                          20                          51
# 2574                           4                          12
# 2575                         NaN                         NaN
# 2576                           4                          12
# 2577                           9                          25
#
#      :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                              1                           1
# ...                          ...                         ...
# 2573                           1                           1
# 2574                           1                           2
# 2575                         NaN                         NaN
# 2576                           1                           1
# 2577                           1                           1
#
#      :@computed_region_sjpq_96s8 :@computed_region_f73m_vb2k  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                          30386                           1
# ...                          ...                         ...
# 2573                         NaN                           1
# 2574                        1527                           2
# 2575                         NaN                         NaN
# 2576                        1527                           2
# 2577                       30813                           9
#
#      :@computed_region_c9xn_skx3 :@computed_region_gisn_y5cm  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                              9                           6
# ...                          ...                         ...
# 2573                          13                           6
# 2574                           4                           4
# 2575                         NaN                         NaN
# 2576                           4                           4
# 2577                          21                           5
#
#      :@computed_region_v3ji_vzam :@computed_region_cfa7_hbpz
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                           2005                         NaN
# ...                          ...                         ...
# 2573                        2005                         NaN
# 2574                        2005                         NaN
# 2575                         NaN                         NaN
# 2576                        2005                         NaN
# 2577                        2005                         NaN
#
# [2578 rows x 18 columns]

# %%
results_df.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 results_df.plot()
#
# File ~\anaconda3\envs\geospatial\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\envs\geospatial\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\envs\geospatial\lib\site-packages\pandas\plotting\_matplotlib\core.py:327, in MPLPlot.generate(self)
#     325 def generate(self):
#     326     self._args_adjust()
# --> 327     self._compute_plot_data()
#     328     self._setup_subplots()
#     329     self._make_plot()
#
# File ~\anaconda3\envs\geospatial\lib\site-packages\pandas\plotting\_matplotlib\core.py:506, in MPLPlot._compute_plot_data(self)
#     504 # no non-numeric frames or series allowed
#     505 if is_empty:
# --> 506     raise TypeError("no numeric data to plot")
#     508 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
